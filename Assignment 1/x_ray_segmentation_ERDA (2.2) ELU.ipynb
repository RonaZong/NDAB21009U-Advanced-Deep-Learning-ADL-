# %% [markdown]
# # U-Net segmentation example
# ### Advanced Deep Learning 2022
# This notebook was originally written by Mathias Perslev. It has been changed slightly by Christian Igel and subsequently slightly updated [Stefan Sommer](mailto:sommer@di.ku.dk).
#
# The U-Net is based on code written by Annika Brundyn and Akshay Kulkarni distributed as part of [*PyTorch Lightning Bolts*](https://pytorch-lightning.readthedocs.io/) under the  [Apache 2.0 license](https://www.apache.org/licenses/LICENSE-2.0.txt).
#
# We consider the data described in:
#
# Bram van Ginneken, Mikkel B. Stegmann, Marco Loog. [Segmentation of anatomical structures in chest radiographs using supervised methods: a comparative study on a public database](https://doi.org/10.1016/j.media.2005.02.002). *Medical Image Analysis* 10(1): 19-40, 2006

# %% [markdown]
# ## Installs
#
# If some packages are missing:

# %%
pip install -q pytorch_lightning lightning-bolts
# Out:
#      |████████████████████████████████| 584 kB 5.1 MB/s
#      |████████████████████████████████| 316 kB 45.8 MB/s
#      |████████████████████████████████| 136 kB 44.9 MB/s
#      |████████████████████████████████| 409 kB 38.7 MB/s
#      |████████████████████████████████| 596 kB 45.2 MB/s
#      |████████████████████████████████| 1.1 MB 41.6 MB/s
#      |████████████████████████████████| 271 kB 43.6 MB/s
#      |████████████████████████████████| 144 kB 46.6 MB/s
#      |████████████████████████████████| 94 kB 956 kB/s

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn as nn
from torch.nn import functional as F
from torchvision.datasets.utils import download_url

import torchmetrics

from pprint import pformat
from skimage.transform import resize
#from sklearn.metrics import f1_score
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

# %% [markdown]
# ## Mount Google drive when using Google Colab

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    os.chdir('gdrive/MyDrive/Colab Notebooks')
except:
    print('Google drive not mounted')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## Test for GPU support

# %%
# GPU support?
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cpu

# %% [markdown]
# ## U-Net
# Import the U-Net.

# %%
from unet import UNet

# %% [markdown]
# ## Database

# %% [markdown]
# Load database with chest X-rays with lung segmentations.

# %%
data_root='./datasets'
data_npz='lung_field_dataset.npz'
data_fn = os.path.join(data_root, "lung_field_dataset.npz")
force_download = False

if (not os.path.exists(data_fn)) or force_download:
  download_url("https://sid.erda.dk/share_redirect/gCTc6o3KAh", data_root, data_npz)
else:
  print('Using existing', data_fn)
# Out:
# Using existing ./datasets/lung_field_dataset.npz

# %%
def plot_image_with_segmentation(image, segmentation, ax=None):
    """
    Plots an image with overlayed segmentation mask
    
    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")
    
    ax.imshow(image.squeeze(), cmap="gray")
    mask = np.ma.masked_where(segmentation == 0, segmentation)
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax


def load_npz_dataset(path, keys=('x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test')):
    archive = np.load(path)
    return [archive.get(key) for key in keys]

# %%
# Load train/val/test data
x_train, y_train, x_val, y_val, x_test, y_test = load_npz_dataset(data_fn)
# Bring images into PyTorch format
x_train = np.moveaxis(x_train, 3, 1)
y_train = np.moveaxis(y_train, 3, 1)
x_val = np.moveaxis(x_val, 3, 1)
y_val = np.moveaxis(y_val, 3, 1)
x_test = np.moveaxis(x_test, 3, 1)
y_test = np.moveaxis(y_test, 3, 1)

print("x train:", x_train.shape)
print("y train:", y_train.shape)
print("x val: ", x_val.shape)
print("y val: ", y_val.shape)
print("x test:", x_test.shape)
print("y test:", y_test.shape)

# Plot an example
fig, ax = plot_image_with_segmentation(x_train[0], y_train[0])
plt.savefig("Plot Image with Segmentation (ELU2)")
plt.show()
# Out:
# x train: (112, 1, 256, 256)
# y train: (112, 1, 256, 256)
# x val:  (12, 1, 256, 256)
# y val:  (12, 1, 256, 256)
# x test: (123, 1, 256, 256)
# y test: (123, 1, 256, 256)

# %% [markdown]
# ### Init torch dataloaders

# %%
def as_torch_dataset(x_arr, y_arr):
    """
    Takes two numpy arrays of data points and labels (x_arr and y_arr, respectively) and
    returns a torch TensorDataset object.
    
    Returns: torch.utils.data.TensorDataset
    """
    dataset = torch.utils.data.TensorDataset(
        torch.FloatTensor(x_arr), 
        torch.LongTensor(y_arr)
    )
    return dataset

# Init torch datasets
train_dataset = as_torch_dataset(x_train, y_train.squeeze(1))  # remove dummy channel dim
val_dataset = as_torch_dataset(x_val, y_val.squeeze(1))
test_dataset = as_torch_dataset(x_test, y_test.squeeze(1))

# Init dataloaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# ### Function for evaluating a model on a data loader

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.
    
    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """
    
    # defaultdict(list) returns a dictionary-like object with default_factory list. 
    # When a new key is encountered, an entry is automatically created of type default_factory. 
    metrics = defaultdict(list)
    with torch.no_grad():
        for batch_x, batch_y in data_loader:
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)
            
            # Compute all metrics
            for metric_name, metric_func in metrics_dict.items():
                value = metric_func(logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                metrics[metric_name].append(value)
    
    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %% [markdown]
# ## Main trainig loop function(s)
#
# We want to track the F1 score during training. This generates some additional code.

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        
        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)
        
        # Compute loss function
        loss_tensor = loss(logits, batch_y)
        loss_scalar = loss_tensor.detach().cpu().numpy()
        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)
        
        # Backprop and step
        loss_tensor.backward()
        optimizer.step()
        
    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model, 
        data_loader=val_loader,
        metrics_dict=metrics_dict
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists
    
    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}
    
    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.
    
    Returns: 
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []
    
    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)
    
    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model, 
                loss=loss, 
                optimizer=optimizer, 
                train_loader=train_loader, 
                val_loader=val_loader, 
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)
            
            if save_path:
                save_path_epoch = f"epoch_{i+1}_{save_path}"
                print(f"   Saving to: {save_path_epoch}")
                save_model(model, save_path_epoch, optimizer)
    except KeyboardInterrupt:
        print("Training stopped.")
        pass
    
    # Merge list of training and validation dicts into single dicts    
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %% [markdown]
# ## Function for plotting training/validation histories

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)
    
    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")
    
    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)
    
    return fig, ax

# %% [markdown]
# ## Functions for saving and loading model and optimizer state

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %% [markdown]
# ## Init U-Net model and optimizer

# %%
# Init U-Net model
model = UNet(
    num_classes=2, 
    input_channels=1, 
    num_layers=4, 
    features_start=16,
)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %% [markdown]
# ## Continue training?

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %% [markdown]
# ## Run training

# %%
# Define loss and metrics
loss = torch.nn.CrossEntropyLoss(reduction="mean")
metrics = {"f1": torchmetrics.classification.F1Score(num_classes=2, average="macro", mdmc_average="samplewise")}

# Run training
train_history, val_history = training_loop(
    model=model,
    loss=loss, 
    optimizer=optimizer, 
    train_loader=train_loader, 
    val_loader=val_loader,
    init_epoch=init_epoch,
    n_epochs=100,
    metrics_dict=metrics,
    save_path="model.ckpt"
)
# Out:
# Epoch 1/100
#    -- Batch 1/7 / Loss:  0.66569203
#    -- Batch 2/7 / Loss:  0.65300393
#    -- Batch 3/7 / Loss:  0.62165296
#    -- Batch 4/7 / Loss:  0.61297613
#    -- Batch 5/7 / Loss:  0.5973067
#    -- Batch 6/7 / Loss:  0.57664156
#    -- Batch 7/7 / Loss:  0.5790655
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.6151913}
#    Validation: {'f1': 0.7683274745941162, 'loss': 0.5510632395744324}
#    Saving to: epoch_1_model.ckpt
# Epoch 2/100
#    -- Batch 1/7 / Loss:  0.562209
#    -- Batch 2/7 / Loss:  0.5430515
#    -- Batch 3/7 / Loss:  0.53004146
#    -- Batch 4/7 / Loss:  0.5240911
#    -- Batch 5/7 / Loss:  0.5367501
#    -- Batch 6/7 / Loss:  0.502534
#    -- Batch 7/7 / Loss:  0.49376962
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.5274924}
#    Validation: {'f1': 0.8102070093154907, 'loss': 0.47938522696495056}
#    Saving to: epoch_2_model.ckpt
# Epoch 3/100
#    -- Batch 1/7 / Loss:  0.49427527
#    -- Batch 2/7 / Loss:  0.47630253
#    -- Batch 3/7 / Loss:  0.46456498
#    -- Batch 4/7 / Loss:  0.46343744
#    -- Batch 5/7 / Loss:  0.45067495
#    -- Batch 6/7 / Loss:  0.44813046
#    -- Batch 7/7 / Loss:  0.4304299
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.4611165}
#    Validation: {'f1': 0.8462442755699158, 'loss': 0.4147539436817169}
#    Saving to: epoch_3_model.ckpt
# Epoch 4/100
#    -- Batch 1/7 / Loss:  0.42405555
#    -- Batch 2/7 / Loss:  0.4048097
#    -- Batch 3/7 / Loss:  0.40448153
#    -- Batch 4/7 / Loss:  0.4415797
#    -- Batch 5/7 / Loss:  0.37195364
#    -- Batch 6/7 / Loss:  0.3732765
#    -- Batch 7/7 / Loss:  0.36271217
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3975527}
#    Validation: {'f1': 0.8976856470108032, 'loss': 0.3565049171447754}
#    Saving to: epoch_4_model.ckpt
# Epoch 5/100
#    -- Batch 1/7 / Loss:  0.35618648
#    -- Batch 2/7 / Loss:  0.36077547
#    -- Batch 3/7 / Loss:  0.35596392
#    -- Batch 4/7 / Loss:  0.3405652
#    -- Batch 5/7 / Loss:  0.33051804
#    -- Batch 6/7 / Loss:  0.3324707
#    -- Batch 7/7 / Loss:  0.32321718
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.34281388}
#    Validation: {'f1': 0.9306502938270569, 'loss': 0.3146170973777771}
#    Saving to: epoch_5_model.ckpt
# Epoch 6/100
#    -- Batch 1/7 / Loss:  0.32399204
#    -- Batch 2/7 / Loss:  0.32121938
#    -- Batch 3/7 / Loss:  0.30571312
#    -- Batch 4/7 / Loss:  0.30801398
#    -- Batch 5/7 / Loss:  0.29787147
#    -- Batch 6/7 / Loss:  0.29750353
#    -- Batch 7/7 / Loss:  0.29016587
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.30635422}
#    Validation: {'f1': 0.9458445310592651, 'loss': 0.2864222824573517}
#    Saving to: epoch_6_model.ckpt
# Epoch 7/100
#    -- Batch 1/7 / Loss:  0.28797457
#    -- Batch 2/7 / Loss:  0.29746833
#    -- Batch 3/7 / Loss:  0.2985005
#    -- Batch 4/7 / Loss:  0.27153903
#    -- Batch 5/7 / Loss:  0.27136776
#    -- Batch 6/7 / Loss:  0.282061
#    -- Batch 7/7 / Loss:  0.2812281
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.28430563}
#    Validation: {'f1': 0.9506298303604126, 'loss': 0.2677290141582489}
#    Saving to: epoch_7_model.ckpt
# Epoch 8/100
#    -- Batch 1/7 / Loss:  0.26249024
#    -- Batch 2/7 / Loss:  0.2737013
#    -- Batch 3/7 / Loss:  0.26852307
#    -- Batch 4/7 / Loss:  0.26029438
#    -- Batch 5/7 / Loss:  0.27533126
#    -- Batch 6/7 / Loss:  0.265756
#    -- Batch 7/7 / Loss:  0.26478857
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.26726928}
#    Validation: {'f1': 0.9580966234207153, 'loss': 0.25764501094818115}
#    Saving to: epoch_8_model.ckpt
# Epoch 9/100
#    -- Batch 1/7 / Loss:  0.27199203
#    -- Batch 2/7 / Loss:  0.25336555
#    -- Batch 3/7 / Loss:  0.2536188
#    -- Batch 4/7 / Loss:  0.25852993
#    -- Batch 5/7 / Loss:  0.24116701
#    -- Batch 6/7 / Loss:  0.26454598
#    -- Batch 7/7 / Loss:  0.24611947
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.25561982}
#    Validation: {'f1': 0.9602934122085571, 'loss': 0.24761755764484406}
#    Saving to: epoch_9_model.ckpt
# Epoch 10/100
#    -- Batch 1/7 / Loss:  0.2578884
#    -- Batch 2/7 / Loss:  0.24827076
#    -- Batch 3/7 / Loss:  0.24122669
#    -- Batch 4/7 / Loss:  0.2367922
#    -- Batch 5/7 / Loss:  0.26360947
#    -- Batch 6/7 / Loss:  0.24163027
#    -- Batch 7/7 / Loss:  0.2350547
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24635322}
#    Validation: {'f1': 0.9642232656478882, 'loss': 0.23906396329402924}
#    Saving to: epoch_10_model.ckpt
# Epoch 11/100
#    -- Batch 1/7 / Loss:  0.24902844
#    -- Batch 2/7 / Loss:  0.23748147
#    -- Batch 3/7 / Loss:  0.23556949
#    -- Batch 4/7 / Loss:  0.24669106
#    -- Batch 5/7 / Loss:  0.22368748
#    -- Batch 6/7 / Loss:  0.24298824
#    -- Batch 7/7 / Loss:  0.23132527
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2381102}
#    Validation: {'f1': 0.9638340473175049, 'loss': 0.22927333414554596}
#    Saving to: epoch_11_model.ckpt
# Epoch 12/100
#    -- Batch 1/7 / Loss:  0.23453467
#    -- Batch 2/7 / Loss:  0.23164731
#    -- Batch 3/7 / Loss:  0.23005982
#    -- Batch 4/7 / Loss:  0.22866951
#    -- Batch 5/7 / Loss:  0.2223354
#    -- Batch 6/7 / Loss:  0.23004067
#    -- Batch 7/7 / Loss:  0.23426189
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23022132}
#    Validation: {'f1': 0.9654942750930786, 'loss': 0.22406136989593506}
#    Saving to: epoch_12_model.ckpt
# Epoch 13/100
#    -- Batch 1/7 / Loss:  0.21620107
#    -- Batch 2/7 / Loss:  0.23304285
#    -- Batch 3/7 / Loss:  0.24738047
#    -- Batch 4/7 / Loss:  0.23958515
#    -- Batch 5/7 / Loss:  0.22077265
#    -- Batch 6/7 / Loss:  0.21674587
#    -- Batch 7/7 / Loss:  0.20648798
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22574516}
#    Validation: {'f1': 0.9653863906860352, 'loss': 0.21972231566905975}
#    Saving to: epoch_13_model.ckpt
# Epoch 14/100
#    -- Batch 1/7 / Loss:  0.21969458
#    -- Batch 2/7 / Loss:  0.21205206
#    -- Batch 3/7 / Loss:  0.22213313
#    -- Batch 4/7 / Loss:  0.21942285
#    -- Batch 5/7 / Loss:  0.23028271
#    -- Batch 6/7 / Loss:  0.22145873
#    -- Batch 7/7 / Loss:  0.21803403
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2204397}
#    Validation: {'f1': 0.9691102504730225, 'loss': 0.21400530636310577}
#    Saving to: epoch_14_model.ckpt
# Epoch 15/100
#    -- Batch 1/7 / Loss:  0.20687762
#    -- Batch 2/7 / Loss:  0.22108951
#    -- Batch 3/7 / Loss:  0.20938466
#    -- Batch 4/7 / Loss:  0.22378336
#    -- Batch 5/7 / Loss:  0.20731837
#    -- Batch 6/7 / Loss:  0.21371529
#    -- Batch 7/7 / Loss:  0.22378877
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2151368}
#    Validation: {'f1': 0.9688400030136108, 'loss': 0.20989097654819489}
#    Saving to: epoch_15_model.ckpt
# Epoch 16/100
#    -- Batch 1/7 / Loss:  0.21255466
#    -- Batch 2/7 / Loss:  0.2121555
#    -- Batch 3/7 / Loss:  0.22003414
#    -- Batch 4/7 / Loss:  0.20414393
#    -- Batch 5/7 / Loss:  0.21370982
#    -- Batch 6/7 / Loss:  0.20528106
#    -- Batch 7/7 / Loss:  0.19506457
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20899193}
#    Validation: {'f1': 0.9699527621269226, 'loss': 0.2037656158208847}
#    Saving to: epoch_16_model.ckpt
# Epoch 17/100
#    -- Batch 1/7 / Loss:  0.19606794
#    -- Batch 2/7 / Loss:  0.21476872
#    -- Batch 3/7 / Loss:  0.20993513
#    -- Batch 4/7 / Loss:  0.19692339
#    -- Batch 5/7 / Loss:  0.2106847
#    -- Batch 6/7 / Loss:  0.19914588
#    -- Batch 7/7 / Loss:  0.19897333
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20378557}
#    Validation: {'f1': 0.9706898927688599, 'loss': 0.20081406831741333}
#    Saving to: epoch_17_model.ckpt
# Epoch 18/100
#    -- Batch 1/7 / Loss:  0.21013595
#    -- Batch 2/7 / Loss:  0.2047329
#    -- Batch 3/7 / Loss:  0.19076361
#    -- Batch 4/7 / Loss:  0.21099964
#    -- Batch 5/7 / Loss:  0.195061
#    -- Batch 6/7 / Loss:  0.18930328
#    -- Batch 7/7 / Loss:  0.19620927
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1996008}
#    Validation: {'f1': 0.9726336598396301, 'loss': 0.1956157237291336}
#    Saving to: epoch_18_model.ckpt
# Epoch 19/100
#    -- Batch 1/7 / Loss:  0.20459467
#    -- Batch 2/7 / Loss:  0.191217
#    -- Batch 3/7 / Loss:  0.1974017
#    -- Batch 4/7 / Loss:  0.20502073
#    -- Batch 5/7 / Loss:  0.1867221
#    -- Batch 6/7 / Loss:  0.19537511
#    -- Batch 7/7 / Loss:  0.18986379
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19574216}
#    Validation: {'f1': 0.9720850586891174, 'loss': 0.19150948524475098}
#    Saving to: epoch_19_model.ckpt
# Epoch 20/100
#    -- Batch 1/7 / Loss:  0.186516
#    -- Batch 2/7 / Loss:  0.20647903
#    -- Batch 3/7 / Loss:  0.185349
#    -- Batch 4/7 / Loss:  0.20161615
#    -- Batch 5/7 / Loss:  0.18773432
#    -- Batch 6/7 / Loss:  0.1845741
#    -- Batch 7/7 / Loss:  0.19119787
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19192378}
#    Validation: {'f1': 0.9727787971496582, 'loss': 0.1881282776594162}
#    Saving to: epoch_20_model.ckpt
# Epoch 21/100
#    -- Batch 1/7 / Loss:  0.20062143
#    -- Batch 2/7 / Loss:  0.18421166
#    -- Batch 3/7 / Loss:  0.18289635
#    -- Batch 4/7 / Loss:  0.19273373
#    -- Batch 5/7 / Loss:  0.18335724
#    -- Batch 6/7 / Loss:  0.19489644
#    -- Batch 7/7 / Loss:  0.18028566
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18842895}
#    Validation: {'f1': 0.9743708968162537, 'loss': 0.1856149435043335}
#    Saving to: epoch_21_model.ckpt
# Epoch 22/100
#    -- Batch 1/7 / Loss:  0.19165559
#    -- Batch 2/7 / Loss:  0.19094324
#    -- Batch 3/7 / Loss:  0.19038607
#    -- Batch 4/7 / Loss:  0.19476758
#    -- Batch 5/7 / Loss:  0.18005753
#    -- Batch 6/7 / Loss:  0.17248823
#    -- Batch 7/7 / Loss:  0.17802337
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18547451}
#    Validation: {'f1': 0.9711867570877075, 'loss': 0.18451879918575287}
#    Saving to: epoch_22_model.ckpt
# Epoch 23/100
#    -- Batch 1/7 / Loss:  0.19980134
#    -- Batch 2/7 / Loss:  0.17546408
#    -- Batch 3/7 / Loss:  0.18679856
#    -- Batch 4/7 / Loss:  0.17587739
#    -- Batch 5/7 / Loss:  0.18136412
#    -- Batch 6/7 / Loss:  0.18331356
#    -- Batch 7/7 / Loss:  0.1800702
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18324132}
#    Validation: {'f1': 0.9737770557403564, 'loss': 0.1797713190317154}
#    Saving to: epoch_23_model.ckpt
# Epoch 24/100
#    -- Batch 1/7 / Loss:  0.18000887
#    -- Batch 2/7 / Loss:  0.19259998
#    -- Batch 3/7 / Loss:  0.1701403
#    -- Batch 4/7 / Loss:  0.17626467
#    -- Batch 5/7 / Loss:  0.18217734
#    -- Batch 6/7 / Loss:  0.17874926
#    -- Batch 7/7 / Loss:  0.17339076
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1790473}
#    Validation: {'f1': 0.9749716520309448, 'loss': 0.1775355488061905}
#    Saving to: epoch_24_model.ckpt
# Epoch 25/100
#    -- Batch 1/7 / Loss:  0.1772385
#    -- Batch 2/7 / Loss:  0.17552674
#    -- Batch 3/7 / Loss:  0.1713301
#    -- Batch 4/7 / Loss:  0.17477387
#    -- Batch 5/7 / Loss:  0.17703517
#    -- Batch 6/7 / Loss:  0.1747888
#    -- Batch 7/7 / Loss:  0.18005344
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17582095}
#    Validation: {'f1': 0.9743835926055908, 'loss': 0.1760093718767166}
#    Saving to: epoch_25_model.ckpt
# Epoch 26/100
#    -- Batch 1/7 / Loss:  0.183531
#    -- Batch 2/7 / Loss:  0.17896774
#    -- Batch 3/7 / Loss:  0.18428773
#    -- Batch 4/7 / Loss:  0.16657259
#    -- Batch 5/7 / Loss:  0.16643186
#    -- Batch 6/7 / Loss:  0.18135054
#    -- Batch 7/7 / Loss:  0.15842432
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17422369}
#    Validation: {'f1': 0.9744318723678589, 'loss': 0.17142720520496368}
#    Saving to: epoch_26_model.ckpt
# Epoch 27/100
#    -- Batch 1/7 / Loss:  0.16145274
#    -- Batch 2/7 / Loss:  0.17537896
#    -- Batch 3/7 / Loss:  0.16741678
#    -- Batch 4/7 / Loss:  0.16649288
#    -- Batch 5/7 / Loss:  0.18397923
#    -- Batch 6/7 / Loss:  0.17333701
#    -- Batch 7/7 / Loss:  0.16923726
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17104211}
#    Validation: {'f1': 0.9725059270858765, 'loss': 0.17560331523418427}
#    Saving to: epoch_27_model.ckpt
# Epoch 28/100
#    -- Batch 1/7 / Loss:  0.17365131
#    -- Batch 2/7 / Loss:  0.1636371
#    -- Batch 3/7 / Loss:  0.17736652
#    -- Batch 4/7 / Loss:  0.1771355
#    -- Batch 5/7 / Loss:  0.16733582
#    -- Batch 6/7 / Loss:  0.16954291
#    -- Batch 7/7 / Loss:  0.15944895
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16973116}
#    Validation: {'f1': 0.9735954999923706, 'loss': 0.17144978046417236}
#    Saving to: epoch_28_model.ckpt
# Epoch 29/100
#    -- Batch 1/7 / Loss:  0.1711161
#    -- Batch 2/7 / Loss:  0.18428184
#    -- Batch 3/7 / Loss:  0.16418673
#    -- Batch 4/7 / Loss:  0.15485929
#    -- Batch 5/7 / Loss:  0.16688864
#    -- Batch 6/7 / Loss:  0.17171551
#    -- Batch 7/7 / Loss:  0.15520757
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16689369}
#    Validation: {'f1': 0.9750031232833862, 'loss': 0.16537915170192719}
#    Saving to: epoch_29_model.ckpt
# Epoch 30/100
#    -- Batch 1/7 / Loss:  0.15694956
#    -- Batch 2/7 / Loss:  0.16308491
#    -- Batch 3/7 / Loss:  0.16883439
#    -- Batch 4/7 / Loss:  0.15795268
#    -- Batch 5/7 / Loss:  0.1669893
#    -- Batch 6/7 / Loss:  0.16200213
#    -- Batch 7/7 / Loss:  0.16426046
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16286764}
#    Validation: {'f1': 0.9758950471878052, 'loss': 0.16179542243480682}
#    Saving to: epoch_30_model.ckpt
# Epoch 31/100
#    -- Batch 1/7 / Loss:  0.17282705
#    -- Batch 2/7 / Loss:  0.157057
#    -- Batch 3/7 / Loss:  0.16005212
#    -- Batch 4/7 / Loss:  0.1523491
#    -- Batch 5/7 / Loss:  0.1553441
#    -- Batch 6/7 / Loss:  0.16387895
#    -- Batch 7/7 / Loss:  0.16225366
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1605374}
#    Validation: {'f1': 0.9763233661651611, 'loss': 0.1597006469964981}
#    Saving to: epoch_31_model.ckpt
# Epoch 32/100
#    -- Batch 1/7 / Loss:  0.16546442
#    -- Batch 2/7 / Loss:  0.15315954
#    -- Batch 3/7 / Loss:  0.15187794
#    -- Batch 4/7 / Loss:  0.16464357
#    -- Batch 5/7 / Loss:  0.1575839
#    -- Batch 6/7 / Loss:  0.15404044
#    -- Batch 7/7 / Loss:  0.15276043
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15707575}
#    Validation: {'f1': 0.9767177104949951, 'loss': 0.15679670870304108}
#    Saving to: epoch_32_model.ckpt
# Epoch 33/100
#    -- Batch 1/7 / Loss:  0.15665574
#    -- Batch 2/7 / Loss:  0.16518179
#    -- Batch 3/7 / Loss:  0.14347824
#    -- Batch 4/7 / Loss:  0.15492082
#    -- Batch 5/7 / Loss:  0.15047668
#    -- Batch 6/7 / Loss:  0.16683868
#    -- Batch 7/7 / Loss:  0.15314794
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15581428}
#    Validation: {'f1': 0.9765292406082153, 'loss': 0.15616868436336517}
#    Saving to: epoch_33_model.ckpt
# Epoch 34/100
#    -- Batch 1/7 / Loss:  0.15568739
#    -- Batch 2/7 / Loss:  0.1540501
#    -- Batch 3/7 / Loss:  0.14735912
#    -- Batch 4/7 / Loss:  0.15665635
#    -- Batch 5/7 / Loss:  0.15379836
#    -- Batch 6/7 / Loss:  0.14939672
#    -- Batch 7/7 / Loss:  0.15219405
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1527346}
#    Validation: {'f1': 0.9758170247077942, 'loss': 0.15540070831775665}
#    Saving to: epoch_34_model.ckpt
# Epoch 35/100
#    -- Batch 1/7 / Loss:  0.15593137
#    -- Batch 2/7 / Loss:  0.14668615
#    -- Batch 3/7 / Loss:  0.148505
#    -- Batch 4/7 / Loss:  0.15854672
#    -- Batch 5/7 / Loss:  0.14572921
#    -- Batch 6/7 / Loss:  0.14862645
#    -- Batch 7/7 / Loss:  0.15096055
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1507122}
#    Validation: {'f1': 0.9770386219024658, 'loss': 0.15154334902763367}
#    Saving to: epoch_35_model.ckpt
# Epoch 36/100
#    -- Batch 1/7 / Loss:  0.15606505
#    -- Batch 2/7 / Loss:  0.15576865
#    -- Batch 3/7 / Loss:  0.14406984
#    -- Batch 4/7 / Loss:  0.14992717
#    -- Batch 5/7 / Loss:  0.1485875
#    -- Batch 6/7 / Loss:  0.14441656
#    -- Batch 7/7 / Loss:  0.14013074
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14842364}
#    Validation: {'f1': 0.9770843982696533, 'loss': 0.1482526808977127}
#    Saving to: epoch_36_model.ckpt
# Epoch 37/100
#    -- Batch 1/7 / Loss:  0.14860871
#    -- Batch 2/7 / Loss:  0.15577492
#    -- Batch 3/7 / Loss:  0.1455884
#    -- Batch 4/7 / Loss:  0.14889677
#    -- Batch 5/7 / Loss:  0.15112042
#    -- Batch 6/7 / Loss:  0.14125346
#    -- Batch 7/7 / Loss:  0.13732135
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14693771}
#    Validation: {'f1': 0.9766212701797485, 'loss': 0.14800991117954254}
#    Saving to: epoch_37_model.ckpt
# Epoch 38/100
#    -- Batch 1/7 / Loss:  0.14291991
#    -- Batch 2/7 / Loss:  0.14580953
#    -- Batch 3/7 / Loss:  0.14346504
#    -- Batch 4/7 / Loss:  0.14872777
#    -- Batch 5/7 / Loss:  0.14495449
#    -- Batch 6/7 / Loss:  0.1453366
#    -- Batch 7/7 / Loss:  0.14616959
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14534041}
#    Validation: {'f1': 0.9746683239936829, 'loss': 0.14967502653598785}
#    Saving to: epoch_38_model.ckpt
# Epoch 39/100
#    -- Batch 1/7 / Loss:  0.14534146
#    -- Batch 2/7 / Loss:  0.13522209
#    -- Batch 3/7 / Loss:  0.15310925
#    -- Batch 4/7 / Loss:  0.13885522
#    -- Batch 5/7 / Loss:  0.1489658
#    -- Batch 6/7 / Loss:  0.13768558
#    -- Batch 7/7 / Loss:  0.1496443
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14411768}
#    Validation: {'f1': 0.9764803647994995, 'loss': 0.14600643515586853}
#    Saving to: epoch_39_model.ckpt
# Epoch 40/100
#    -- Batch 1/7 / Loss:  0.13198116
#    -- Batch 2/7 / Loss:  0.14538257
#    -- Batch 3/7 / Loss:  0.15561526
#    -- Batch 4/7 / Loss:  0.14314698
#    -- Batch 5/7 / Loss:  0.14585765
#    -- Batch 6/7 / Loss:  0.14548445
#    -- Batch 7/7 / Loss:  0.1296383
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14244376}
#    Validation: {'f1': 0.9758023023605347, 'loss': 0.14451706409454346}
#    Saving to: epoch_40_model.ckpt
# Epoch 41/100
#    -- Batch 1/7 / Loss:  0.14581765
#    -- Batch 2/7 / Loss:  0.14413145
#    -- Batch 3/7 / Loss:  0.13594212
#    -- Batch 4/7 / Loss:  0.1440355
#    -- Batch 5/7 / Loss:  0.13508072
#    -- Batch 6/7 / Loss:  0.13968027
#    -- Batch 7/7 / Loss:  0.13624719
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14013354}
#    Validation: {'f1': 0.9767048358917236, 'loss': 0.1421533077955246}
#    Saving to: epoch_41_model.ckpt
# Epoch 42/100
#    -- Batch 1/7 / Loss:  0.13365431
#    -- Batch 2/7 / Loss:  0.13494296
#    -- Batch 3/7 / Loss:  0.13328443
#    -- Batch 4/7 / Loss:  0.14736633
#    -- Batch 5/7 / Loss:  0.13489524
#    -- Batch 6/7 / Loss:  0.1406522
#    -- Batch 7/7 / Loss:  0.14371946
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13835928}
#    Validation: {'f1': 0.975814938545227, 'loss': 0.14335878193378448}
#    Saving to: epoch_42_model.ckpt
# Epoch 43/100
#    -- Batch 1/7 / Loss:  0.14120567
#    -- Batch 2/7 / Loss:  0.14409193
#    -- Batch 3/7 / Loss:  0.13022429
#    -- Batch 4/7 / Loss:  0.14193887
#    -- Batch 5/7 / Loss:  0.1274561
#    -- Batch 6/7 / Loss:  0.12848489
#    -- Batch 7/7 / Loss:  0.1397027
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13615778}
#    Validation: {'f1': 0.9775645732879639, 'loss': 0.1375081092119217}
#    Saving to: epoch_43_model.ckpt
# Epoch 44/100
#    -- Batch 1/7 / Loss:  0.1318872
#    -- Batch 2/7 / Loss:  0.13097878
#    -- Batch 3/7 / Loss:  0.1322519
#    -- Batch 4/7 / Loss:  0.13070364
#    -- Batch 5/7 / Loss:  0.13734558
#    -- Batch 6/7 / Loss:  0.12905245
#    -- Batch 7/7 / Loss:  0.14376062
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13371146}
#    Validation: {'f1': 0.9778022766113281, 'loss': 0.13591644167900085}
#    Saving to: epoch_44_model.ckpt
# Epoch 45/100
#    -- Batch 1/7 / Loss:  0.13312134
#    -- Batch 2/7 / Loss:  0.13685408
#    -- Batch 3/7 / Loss:  0.12428719
#    -- Batch 4/7 / Loss:  0.12703706
#    -- Batch 5/7 / Loss:  0.13234031
#    -- Batch 6/7 / Loss:  0.1325455
#    -- Batch 7/7 / Loss:  0.1378754
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1320087}
#    Validation: {'f1': 0.9777094125747681, 'loss': 0.13473369181156158}
#    Saving to: epoch_45_model.ckpt
# Epoch 46/100
#    -- Batch 1/7 / Loss:  0.1205905
#    -- Batch 2/7 / Loss:  0.13753872
#    -- Batch 3/7 / Loss:  0.13281116
#    -- Batch 4/7 / Loss:  0.14207457
#    -- Batch 5/7 / Loss:  0.12518378
#    -- Batch 6/7 / Loss:  0.13379
#    -- Batch 7/7 / Loss:  0.12802753
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1314309}
#    Validation: {'f1': 0.9770124554634094, 'loss': 0.13456027209758759}
#    Saving to: epoch_46_model.ckpt
# Epoch 47/100
#    -- Batch 1/7 / Loss:  0.12914206
#    -- Batch 2/7 / Loss:  0.13072944
#    -- Batch 3/7 / Loss:  0.12939939
#    -- Batch 4/7 / Loss:  0.13366935
#    -- Batch 5/7 / Loss:  0.12082368
#    -- Batch 6/7 / Loss:  0.13027552
#    -- Batch 7/7 / Loss:  0.12741093
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12877862}
#    Validation: {'f1': 0.977774977684021, 'loss': 0.13274621963500977}
#    Saving to: epoch_47_model.ckpt
# Epoch 48/100
#    -- Batch 1/7 / Loss:  0.12863365
#    -- Batch 2/7 / Loss:  0.12506871
#    -- Batch 3/7 / Loss:  0.1317086
#    -- Batch 4/7 / Loss:  0.121995814
#    -- Batch 5/7 / Loss:  0.12043645
#    -- Batch 6/7 / Loss:  0.13132502
#    -- Batch 7/7 / Loss:  0.12569106
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12640847}
#    Validation: {'f1': 0.9780210256576538, 'loss': 0.1306309849023819}
#    Saving to: epoch_48_model.ckpt
# Epoch 49/100
#    -- Batch 1/7 / Loss:  0.13672233
#    -- Batch 2/7 / Loss:  0.12672602
#    -- Batch 3/7 / Loss:  0.117315054
#    -- Batch 4/7 / Loss:  0.12604488
#    -- Batch 5/7 / Loss:  0.12747219
#    -- Batch 6/7 / Loss:  0.12645638
#    -- Batch 7/7 / Loss:  0.120319024
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12586512}
#    Validation: {'f1': 0.978352427482605, 'loss': 0.12875454127788544}
#    Saving to: epoch_49_model.ckpt
# Epoch 50/100
#    -- Batch 1/7 / Loss:  0.12087687
#    -- Batch 2/7 / Loss:  0.13333681
#    -- Batch 3/7 / Loss:  0.12054629
#    -- Batch 4/7 / Loss:  0.123831816
#    -- Batch 5/7 / Loss:  0.12491143
#    -- Batch 6/7 / Loss:  0.11676273
#    -- Batch 7/7 / Loss:  0.12174916
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12314502}
#    Validation: {'f1': 0.9786937832832336, 'loss': 0.1262228935956955}
#    Saving to: epoch_50_model.ckpt
# Epoch 51/100
#    -- Batch 1/7 / Loss:  0.124783516
#    -- Batch 2/7 / Loss:  0.12206314
#    -- Batch 3/7 / Loss:  0.11798968
#    -- Batch 4/7 / Loss:  0.11623607
#    -- Batch 5/7 / Loss:  0.11773108
#    -- Batch 6/7 / Loss:  0.13576248
#    -- Batch 7/7 / Loss:  0.12251373
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12243996}
#    Validation: {'f1': 0.9777208566665649, 'loss': 0.1273147016763687}
#    Saving to: epoch_51_model.ckpt
# Epoch 52/100
#    -- Batch 1/7 / Loss:  0.12776157
#    -- Batch 2/7 / Loss:  0.117970064
#    -- Batch 3/7 / Loss:  0.11606382
#    -- Batch 4/7 / Loss:  0.11776455
#    -- Batch 5/7 / Loss:  0.12207868
#    -- Batch 6/7 / Loss:  0.12062464
#    -- Batch 7/7 / Loss:  0.11842904
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12009891}
#    Validation: {'f1': 0.9780783653259277, 'loss': 0.12530216574668884}
#    Saving to: epoch_52_model.ckpt
# Epoch 53/100
#    -- Batch 1/7 / Loss:  0.12564664
#    -- Batch 2/7 / Loss:  0.112782404
#    -- Batch 3/7 / Loss:  0.11961494
#    -- Batch 4/7 / Loss:  0.1304746
#    -- Batch 5/7 / Loss:  0.11581131
#    -- Batch 6/7 / Loss:  0.11486988
#    -- Batch 7/7 / Loss:  0.117749736
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11956422}
#    Validation: {'f1': 0.9785890579223633, 'loss': 0.12289471179246902}
#    Saving to: epoch_53_model.ckpt
# Epoch 54/100
#    -- Batch 1/7 / Loss:  0.1218193
#    -- Batch 2/7 / Loss:  0.11324657
#    -- Batch 3/7 / Loss:  0.1193438
#    -- Batch 4/7 / Loss:  0.115899
#    -- Batch 5/7 / Loss:  0.11499297
#    -- Batch 6/7 / Loss:  0.11544163
#    -- Batch 7/7 / Loss:  0.11735393
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11687102}
#    Validation: {'f1': 0.9787203073501587, 'loss': 0.12106340378522873}
#    Saving to: epoch_54_model.ckpt
# Epoch 55/100
#    -- Batch 1/7 / Loss:  0.1283401
#    -- Batch 2/7 / Loss:  0.10711233
#    -- Batch 3/7 / Loss:  0.12442531
#    -- Batch 4/7 / Loss:  0.11954606
#    -- Batch 5/7 / Loss:  0.11185323
#    -- Batch 6/7 / Loss:  0.11365543
#    -- Batch 7/7 / Loss:  0.11174196
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11666777}
#    Validation: {'f1': 0.9785565733909607, 'loss': 0.11991893500089645}
#    Saving to: epoch_55_model.ckpt
# Epoch 56/100
#    -- Batch 1/7 / Loss:  0.109681636
#    -- Batch 2/7 / Loss:  0.12142599
#    -- Batch 3/7 / Loss:  0.11526903
#    -- Batch 4/7 / Loss:  0.11434571
#    -- Batch 5/7 / Loss:  0.11237509
#    -- Batch 6/7 / Loss:  0.115817286
#    -- Batch 7/7 / Loss:  0.11272287
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11451966}
#    Validation: {'f1': 0.978550910949707, 'loss': 0.11909136921167374}
#    Saving to: epoch_56_model.ckpt
# Epoch 57/100
#    -- Batch 1/7 / Loss:  0.11513745
#    -- Batch 2/7 / Loss:  0.10386266
#    -- Batch 3/7 / Loss:  0.10792651
#    -- Batch 4/7 / Loss:  0.10892173
#    -- Batch 5/7 / Loss:  0.12612599
#    -- Batch 6/7 / Loss:  0.11866146
#    -- Batch 7/7 / Loss:  0.11894822
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11422629}
#    Validation: {'f1': 0.9760491847991943, 'loss': 0.12479876726865768}
#    Saving to: epoch_57_model.ckpt
# Epoch 58/100
#    -- Batch 1/7 / Loss:  0.11706359
#    -- Batch 2/7 / Loss:  0.10999231
#    -- Batch 3/7 / Loss:  0.11859084
#    -- Batch 4/7 / Loss:  0.11507139
#    -- Batch 5/7 / Loss:  0.11732466
#    -- Batch 6/7 / Loss:  0.11233783
#    -- Batch 7/7 / Loss:  0.10763299
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.114001945}
#    Validation: {'f1': 0.9769383668899536, 'loss': 0.12213379889726639}
#    Saving to: epoch_58_model.ckpt
# Epoch 59/100
#    -- Batch 1/7 / Loss:  0.112749584
#    -- Batch 2/7 / Loss:  0.112833075
#    -- Batch 3/7 / Loss:  0.10764353
#    -- Batch 4/7 / Loss:  0.111106634
#    -- Batch 5/7 / Loss:  0.11381273
#    -- Batch 6/7 / Loss:  0.121100366
#    -- Batch 7/7 / Loss:  0.10436738
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11194476}
#    Validation: {'f1': 0.9776513576507568, 'loss': 0.11775088310241699}
#    Saving to: epoch_59_model.ckpt
# Epoch 60/100
#    -- Batch 1/7 / Loss:  0.115177415
#    -- Batch 2/7 / Loss:  0.117138475
#    -- Batch 3/7 / Loss:  0.104352765
#    -- Batch 4/7 / Loss:  0.104641765
#    -- Batch 5/7 / Loss:  0.11016718
#    -- Batch 6/7 / Loss:  0.10461146
#    -- Batch 7/7 / Loss:  0.1196407
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11081854}
#    Validation: {'f1': 0.9789838790893555, 'loss': 0.1144716814160347}
#    Saving to: epoch_60_model.ckpt
# Epoch 61/100
#    -- Batch 1/7 / Loss:  0.10057678
#    -- Batch 2/7 / Loss:  0.11434924
#    -- Batch 3/7 / Loss:  0.10616735
#    -- Batch 4/7 / Loss:  0.10806149
#    -- Batch 5/7 / Loss:  0.11077156
#    -- Batch 6/7 / Loss:  0.11264488
#    -- Batch 7/7 / Loss:  0.11228258
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10926484}
#    Validation: {'f1': 0.9784514307975769, 'loss': 0.11450901627540588}
#    Saving to: epoch_61_model.ckpt
# Epoch 62/100
#    -- Batch 1/7 / Loss:  0.10071923
#    -- Batch 2/7 / Loss:  0.107483685
#    -- Batch 3/7 / Loss:  0.11269273
#    -- Batch 4/7 / Loss:  0.10985025
#    -- Batch 5/7 / Loss:  0.10751029
#    -- Batch 6/7 / Loss:  0.11374469
#    -- Batch 7/7 / Loss:  0.10341229
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10791616}
#    Validation: {'f1': 0.9774217009544373, 'loss': 0.11584401875734329}
#    Saving to: epoch_62_model.ckpt
# Epoch 63/100
#    -- Batch 1/7 / Loss:  0.11497843
#    -- Batch 2/7 / Loss:  0.09909509
#    -- Batch 3/7 / Loss:  0.10303377
#    -- Batch 4/7 / Loss:  0.104865074
#    -- Batch 5/7 / Loss:  0.11218491
#    -- Batch 6/7 / Loss:  0.10096088
#    -- Batch 7/7 / Loss:  0.109077446
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10631365}
#    Validation: {'f1': 0.9781501889228821, 'loss': 0.11321187764406204}
#    Saving to: epoch_63_model.ckpt
# Epoch 64/100
#    -- Batch 1/7 / Loss:  0.10334471
#    -- Batch 2/7 / Loss:  0.10422496
#    -- Batch 3/7 / Loss:  0.10145878
#    -- Batch 4/7 / Loss:  0.11280297
#    -- Batch 5/7 / Loss:  0.09993163
#    -- Batch 6/7 / Loss:  0.11070835
#    -- Batch 7/7 / Loss:  0.10002729
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10464268}
#    Validation: {'f1': 0.9781395196914673, 'loss': 0.11086628586053848}
#    Saving to: epoch_64_model.ckpt
# Epoch 65/100
#    -- Batch 1/7 / Loss:  0.10600088
#    -- Batch 2/7 / Loss:  0.1032009
#    -- Batch 3/7 / Loss:  0.10851126
#    -- Batch 4/7 / Loss:  0.0998736
#    -- Batch 5/7 / Loss:  0.103536315
#    -- Batch 6/7 / Loss:  0.10103544
#    -- Batch 7/7 / Loss:  0.10114115
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10332851}
#    Validation: {'f1': 0.9793047308921814, 'loss': 0.1094430685043335}
#    Saving to: epoch_65_model.ckpt
# Epoch 66/100
#    -- Batch 1/7 / Loss:  0.10255303
#    -- Batch 2/7 / Loss:  0.11353089
#    -- Batch 3/7 / Loss:  0.09751042
#    -- Batch 4/7 / Loss:  0.10303552
#    -- Batch 5/7 / Loss:  0.09914048
#    -- Batch 6/7 / Loss:  0.09779104
#    -- Batch 7/7 / Loss:  0.10542548
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1027124}
#    Validation: {'f1': 0.9784651398658752, 'loss': 0.10905244201421738}
#    Saving to: epoch_66_model.ckpt
# Epoch 67/100
#    -- Batch 1/7 / Loss:  0.113750316
#    -- Batch 2/7 / Loss:  0.097461015
#    -- Batch 3/7 / Loss:  0.10004688
#    -- Batch 4/7 / Loss:  0.10093075
#    -- Batch 5/7 / Loss:  0.10014416
#    -- Batch 6/7 / Loss:  0.09982307
#    -- Batch 7/7 / Loss:  0.10283021
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10214091}
#    Validation: {'f1': 0.9765450954437256, 'loss': 0.11183198541402817}
#    Saving to: epoch_67_model.ckpt
# Epoch 68/100
#    -- Batch 1/7 / Loss:  0.106911525
#    -- Batch 2/7 / Loss:  0.10596867
#    -- Batch 3/7 / Loss:  0.09610967
#    -- Batch 4/7 / Loss:  0.096739255
#    -- Batch 5/7 / Loss:  0.099271186
#    -- Batch 6/7 / Loss:  0.09272027
#    -- Batch 7/7 / Loss:  0.107938625
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.100808464}
#    Validation: {'f1': 0.9787771701812744, 'loss': 0.10669302940368652}
#    Saving to: epoch_68_model.ckpt
# Epoch 69/100
#    -- Batch 1/7 / Loss:  0.10126941
#    -- Batch 2/7 / Loss:  0.1046091
#    -- Batch 3/7 / Loss:  0.09560311
#    -- Batch 4/7 / Loss:  0.09528997
#    -- Batch 5/7 / Loss:  0.10842337
#    -- Batch 6/7 / Loss:  0.091567606
#    -- Batch 7/7 / Loss:  0.09925691
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09943135}
#    Validation: {'f1': 0.9786733984947205, 'loss': 0.10632292181253433}
#    Saving to: epoch_69_model.ckpt
# Epoch 70/100
#    -- Batch 1/7 / Loss:  0.1090248
#    -- Batch 2/7 / Loss:  0.09962805
#    -- Batch 3/7 / Loss:  0.09369743
#    -- Batch 4/7 / Loss:  0.09284247
#    -- Batch 5/7 / Loss:  0.10167971
#    -- Batch 6/7 / Loss:  0.10085265
#    -- Batch 7/7 / Loss:  0.08823206
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09799387}
#    Validation: {'f1': 0.9782955646514893, 'loss': 0.10565706342458725}
#    Saving to: epoch_70_model.ckpt
# Epoch 71/100
#    -- Batch 1/7 / Loss:  0.09681394
#    -- Batch 2/7 / Loss:  0.09416501
#    -- Batch 3/7 / Loss:  0.095056646
#    -- Batch 4/7 / Loss:  0.0887213
#    -- Batch 5/7 / Loss:  0.097666994
#    -- Batch 6/7 / Loss:  0.10210513
#    -- Batch 7/7 / Loss:  0.1005044
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09643335}
#    Validation: {'f1': 0.9777451753616333, 'loss': 0.10754617303609848}
#    Saving to: epoch_71_model.ckpt
# Epoch 72/100
#    -- Batch 1/7 / Loss:  0.09525365
#    -- Batch 2/7 / Loss:  0.10875306
#    -- Batch 3/7 / Loss:  0.09611537
#    -- Batch 4/7 / Loss:  0.08988261
#    -- Batch 5/7 / Loss:  0.09311176
#    -- Batch 6/7 / Loss:  0.09967698
#    -- Batch 7/7 / Loss:  0.089639746
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09606188}
#    Validation: {'f1': 0.9780761003494263, 'loss': 0.10457058995962143}
#    Saving to: epoch_72_model.ckpt
# Epoch 73/100
#    -- Batch 1/7 / Loss:  0.089569695
#    -- Batch 2/7 / Loss:  0.091360085
#    -- Batch 3/7 / Loss:  0.094417684
#    -- Batch 4/7 / Loss:  0.09076692
#    -- Batch 5/7 / Loss:  0.09373874
#    -- Batch 6/7 / Loss:  0.10554057
#    -- Batch 7/7 / Loss:  0.096182354
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09451086}
#    Validation: {'f1': 0.9784708023071289, 'loss': 0.10410664230585098}
#    Saving to: epoch_73_model.ckpt
# Epoch 74/100
#    -- Batch 1/7 / Loss:  0.10308858
#    -- Batch 2/7 / Loss:  0.08995277
#    -- Batch 3/7 / Loss:  0.09586782
#    -- Batch 4/7 / Loss:  0.094741136
#    -- Batch 5/7 / Loss:  0.09145264
#    -- Batch 6/7 / Loss:  0.08676579
#    -- Batch 7/7 / Loss:  0.09312614
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.093570694}
#    Validation: {'f1': 0.9793649911880493, 'loss': 0.10070246458053589}
#    Saving to: epoch_74_model.ckpt
# Epoch 75/100
#    -- Batch 1/7 / Loss:  0.09499753
#    -- Batch 2/7 / Loss:  0.092882656
#    -- Batch 3/7 / Loss:  0.091992356
#    -- Batch 4/7 / Loss:  0.09386397
#    -- Batch 5/7 / Loss:  0.08963678
#    -- Batch 6/7 / Loss:  0.08962969
#    -- Batch 7/7 / Loss:  0.09219694
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.092171416}
#    Validation: {'f1': 0.9787118434906006, 'loss': 0.10122080892324448}
#    Saving to: epoch_75_model.ckpt
# Epoch 76/100
#    -- Batch 1/7 / Loss:  0.08468645
#    -- Batch 2/7 / Loss:  0.0920766
#    -- Batch 3/7 / Loss:  0.09725649
#    -- Batch 4/7 / Loss:  0.09141429
#    -- Batch 5/7 / Loss:  0.09441219
#    -- Batch 6/7 / Loss:  0.09268771
#    -- Batch 7/7 / Loss:  0.08987485
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09177266}
#    Validation: {'f1': 0.9778345823287964, 'loss': 0.10305073112249374}
#    Saving to: epoch_76_model.ckpt
# Epoch 77/100
#    -- Batch 1/7 / Loss:  0.09624492
#    -- Batch 2/7 / Loss:  0.08245007
#    -- Batch 3/7 / Loss:  0.09765289
#    -- Batch 4/7 / Loss:  0.08958082
#    -- Batch 5/7 / Loss:  0.089613065
#    -- Batch 6/7 / Loss:  0.08492444
#    -- Batch 7/7 / Loss:  0.09805537
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.09121738}
#    Validation: {'f1': 0.9780607223510742, 'loss': 0.1022702232003212}
#    Saving to: epoch_77_model.ckpt
# Epoch 78/100
#    -- Batch 1/7 / Loss:  0.08952661
#    -- Batch 2/7 / Loss:  0.08885736
#    -- Batch 3/7 / Loss:  0.08550722
#    -- Batch 4/7 / Loss:  0.091213435
#    -- Batch 5/7 / Loss:  0.09001226
#    -- Batch 6/7 / Loss:  0.09496952
#    -- Batch 7/7 / Loss:  0.086446784
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08950473}
#    Validation: {'f1': 0.9787003397941589, 'loss': 0.10034111887216568}
#    Saving to: epoch_78_model.ckpt
# Epoch 79/100
#    -- Batch 1/7 / Loss:  0.08538451
#    -- Batch 2/7 / Loss:  0.09610288
#    -- Batch 3/7 / Loss:  0.0826911
#    -- Batch 4/7 / Loss:  0.0971147
#    -- Batch 5/7 / Loss:  0.082055405
#    -- Batch 6/7 / Loss:  0.09373584
#    -- Batch 7/7 / Loss:  0.09073216
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08968808}
#    Validation: {'f1': 0.9782007932662964, 'loss': 0.09926909953355789}
#    Saving to: epoch_79_model.ckpt
# Epoch 80/100
#    -- Batch 1/7 / Loss:  0.08919583
#    -- Batch 2/7 / Loss:  0.09496655
#    -- Batch 3/7 / Loss:  0.08586884
#    -- Batch 4/7 / Loss:  0.086210296
#    -- Batch 5/7 / Loss:  0.088156566
#    -- Batch 6/7 / Loss:  0.08386289
#    -- Batch 7/7 / Loss:  0.08895566
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08817381}
#    Validation: {'f1': 0.97894287109375, 'loss': 0.09744012355804443}
#    Saving to: epoch_80_model.ckpt
# Epoch 81/100
#    -- Batch 1/7 / Loss:  0.085666336
#    -- Batch 2/7 / Loss:  0.08468582
#    -- Batch 3/7 / Loss:  0.083342806
#    -- Batch 4/7 / Loss:  0.082638904
#    -- Batch 5/7 / Loss:  0.0897575
#    -- Batch 6/7 / Loss:  0.08399523
#    -- Batch 7/7 / Loss:  0.09713697
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08674622}
#    Validation: {'f1': 0.9787447452545166, 'loss': 0.0971505269408226}
#    Saving to: epoch_81_model.ckpt
# Epoch 82/100
#    -- Batch 1/7 / Loss:  0.080152944
#    -- Batch 2/7 / Loss:  0.09241206
#    -- Batch 3/7 / Loss:  0.0837446
#    -- Batch 4/7 / Loss:  0.08774906
#    -- Batch 5/7 / Loss:  0.082031846
#    -- Batch 6/7 / Loss:  0.08936641
#    -- Batch 7/7 / Loss:  0.08660276
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.086008534}
#    Validation: {'f1': 0.9786007404327393, 'loss': 0.09651041775941849}
#    Saving to: epoch_82_model.ckpt
# Epoch 83/100
#    -- Batch 1/7 / Loss:  0.09700527
#    -- Batch 2/7 / Loss:  0.08764517
#    -- Batch 3/7 / Loss:  0.081455715
#    -- Batch 4/7 / Loss:  0.091378205
#    -- Batch 5/7 / Loss:  0.0806018
#    -- Batch 6/7 / Loss:  0.07831075
#    -- Batch 7/7 / Loss:  0.080858335
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08532218}
#    Validation: {'f1': 0.9787837266921997, 'loss': 0.09556412696838379}
#    Saving to: epoch_83_model.ckpt
# Epoch 84/100
#    -- Batch 1/7 / Loss:  0.08668244
#    -- Batch 2/7 / Loss:  0.088675596
#    -- Batch 3/7 / Loss:  0.083346434
#    -- Batch 4/7 / Loss:  0.084846824
#    -- Batch 5/7 / Loss:  0.08110428
#    -- Batch 6/7 / Loss:  0.081261836
#    -- Batch 7/7 / Loss:  0.083785005
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08424319}
#    Validation: {'f1': 0.978378415107727, 'loss': 0.09490891546010971}
#    Saving to: epoch_84_model.ckpt
# Epoch 85/100
#    -- Batch 1/7 / Loss:  0.07566715
#    -- Batch 2/7 / Loss:  0.08380734
#    -- Batch 3/7 / Loss:  0.08287527
#    -- Batch 4/7 / Loss:  0.08891745
#    -- Batch 5/7 / Loss:  0.08342204
#    -- Batch 6/7 / Loss:  0.08482872
#    -- Batch 7/7 / Loss:  0.085855275
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08362476}
#    Validation: {'f1': 0.9783121943473816, 'loss': 0.09620485454797745}
#    Saving to: epoch_85_model.ckpt
# Epoch 86/100
#    -- Batch 1/7 / Loss:  0.081761986
#    -- Batch 2/7 / Loss:  0.087491296
#    -- Batch 3/7 / Loss:  0.0778561
#    -- Batch 4/7 / Loss:  0.07706181
#    -- Batch 5/7 / Loss:  0.07821274
#    -- Batch 6/7 / Loss:  0.08271415
#    -- Batch 7/7 / Loss:  0.09006111
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0821656}
#    Validation: {'f1': 0.978839635848999, 'loss': 0.09383540600538254}
#    Saving to: epoch_86_model.ckpt
# Epoch 87/100
#    -- Batch 1/7 / Loss:  0.08091789
#    -- Batch 2/7 / Loss:  0.07961816
#    -- Batch 3/7 / Loss:  0.07504577
#    -- Batch 4/7 / Loss:  0.08349921
#    -- Batch 5/7 / Loss:  0.08427111
#    -- Batch 6/7 / Loss:  0.08389194
#    -- Batch 7/7 / Loss:  0.09152138
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.08268078}
#    Validation: {'f1': 0.9772707223892212, 'loss': 0.09628787636756897}
#    Saving to: epoch_87_model.ckpt
# Epoch 88/100
#    -- Batch 1/7 / Loss:  0.088713475
#    -- Batch 2/7 / Loss:  0.082461186
#    -- Batch 3/7 / Loss:  0.08241941
#    -- Batch 4/7 / Loss:  0.08263423
#    -- Batch 5/7 / Loss:  0.07678444
#    -- Batch 6/7 / Loss:  0.085024044
#    -- Batch 7/7 / Loss:  0.08201875
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.082865074}
#    Validation: {'f1': 0.9784559607505798, 'loss': 0.09382698684930801}
#    Saving to: epoch_88_model.ckpt
# Epoch 89/100
#    -- Batch 1/7 / Loss:  0.08020258
#    -- Batch 2/7 / Loss:  0.07916066
#    -- Batch 3/7 / Loss:  0.07744725
#    -- Batch 4/7 / Loss:  0.080514744
#    -- Batch 5/7 / Loss:  0.08004349
#    -- Batch 6/7 / Loss:  0.08111894
#    -- Batch 7/7 / Loss:  0.08145667
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07999205}
#    Validation: {'f1': 0.9788421392440796, 'loss': 0.09118509292602539}
#    Saving to: epoch_89_model.ckpt
# Epoch 90/100
#    -- Batch 1/7 / Loss:  0.076665126
#    -- Batch 2/7 / Loss:  0.07668194
#    -- Batch 3/7 / Loss:  0.077014714
#    -- Batch 4/7 / Loss:  0.07806972
#    -- Batch 5/7 / Loss:  0.081349336
#    -- Batch 6/7 / Loss:  0.083647594
#    -- Batch 7/7 / Loss:  0.07633742
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07853798}
#    Validation: {'f1': 0.9792047739028931, 'loss': 0.0909322202205658}
#    Saving to: epoch_90_model.ckpt
# Epoch 91/100
#    -- Batch 1/7 / Loss:  0.07737888
#    -- Batch 2/7 / Loss:  0.07870545
#    -- Batch 3/7 / Loss:  0.07365874
#    -- Batch 4/7 / Loss:  0.07473444
#    -- Batch 5/7 / Loss:  0.079977706
#    -- Batch 6/7 / Loss:  0.07617525
#    -- Batch 7/7 / Loss:  0.0820356
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07752372}
#    Validation: {'f1': 0.978785514831543, 'loss': 0.09111374616622925}
#    Saving to: epoch_91_model.ckpt
# Epoch 92/100
#    -- Batch 1/7 / Loss:  0.08703011
#    -- Batch 2/7 / Loss:  0.076724775
#    -- Batch 3/7 / Loss:  0.07636608
#    -- Batch 4/7 / Loss:  0.076635644
#    -- Batch 5/7 / Loss:  0.07235922
#    -- Batch 6/7 / Loss:  0.08246044
#    -- Batch 7/7 / Loss:  0.07537756
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07813626}
#    Validation: {'f1': 0.9783415794372559, 'loss': 0.09024810791015625}
#    Saving to: epoch_92_model.ckpt
# Epoch 93/100
#    -- Batch 1/7 / Loss:  0.07640387
#    -- Batch 2/7 / Loss:  0.07192182
#    -- Batch 3/7 / Loss:  0.07710552
#    -- Batch 4/7 / Loss:  0.08101217
#    -- Batch 5/7 / Loss:  0.07241642
#    -- Batch 6/7 / Loss:  0.07941307
#    -- Batch 7/7 / Loss:  0.078319855
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.0766561}
#    Validation: {'f1': 0.9790445566177368, 'loss': 0.08912085741758347}
#    Saving to: epoch_93_model.ckpt
# Epoch 94/100
#    -- Batch 1/7 / Loss:  0.0733301
#    -- Batch 2/7 / Loss:  0.07542342
#    -- Batch 3/7 / Loss:  0.07174402
#    -- Batch 4/7 / Loss:  0.077771485
#    -- Batch 5/7 / Loss:  0.07393347
#    -- Batch 6/7 / Loss:  0.07947482
#    -- Batch 7/7 / Loss:  0.07498415
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07523735}
#    Validation: {'f1': 0.9787439107894897, 'loss': 0.08961889147758484}
#    Saving to: epoch_94_model.ckpt
# Epoch 95/100
#    -- Batch 1/7 / Loss:  0.07598701
#    -- Batch 2/7 / Loss:  0.072007224
#    -- Batch 3/7 / Loss:  0.08209741
#    -- Batch 4/7 / Loss:  0.07584886
#    -- Batch 5/7 / Loss:  0.06926395
#    -- Batch 6/7 / Loss:  0.080923535
#    -- Batch 7/7 / Loss:  0.07095541
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07529763}
#    Validation: {'f1': 0.9783471822738647, 'loss': 0.08970210701227188}
#    Saving to: epoch_95_model.ckpt
# Epoch 96/100
#    -- Batch 1/7 / Loss:  0.07261179
#    -- Batch 2/7 / Loss:  0.07428804
#    -- Batch 3/7 / Loss:  0.07470053
#    -- Batch 4/7 / Loss:  0.075710736
#    -- Batch 5/7 / Loss:  0.069949776
#    -- Batch 6/7 / Loss:  0.071658604
#    -- Batch 7/7 / Loss:  0.08014656
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07415229}
#    Validation: {'f1': 0.9788397550582886, 'loss': 0.08819886296987534}
#    Saving to: epoch_96_model.ckpt
# Epoch 97/100
#    -- Batch 1/7 / Loss:  0.071794674
#    -- Batch 2/7 / Loss:  0.07022855
#    -- Batch 3/7 / Loss:  0.07598324
#    -- Batch 4/7 / Loss:  0.079102926
#    -- Batch 5/7 / Loss:  0.075014874
#    -- Batch 6/7 / Loss:  0.06886647
#    -- Batch 7/7 / Loss:  0.07213657
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07330389}
#    Validation: {'f1': 0.9787957072257996, 'loss': 0.08770286291837692}
#    Saving to: epoch_97_model.ckpt
# Epoch 98/100
#    -- Batch 1/7 / Loss:  0.07133227
#    -- Batch 2/7 / Loss:  0.07396553
#    -- Batch 3/7 / Loss:  0.07085905
#    -- Batch 4/7 / Loss:  0.08196703
#    -- Batch 5/7 / Loss:  0.07542984
#    -- Batch 6/7 / Loss:  0.07010153
#    -- Batch 7/7 / Loss:  0.06991904
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07336775}
#    Validation: {'f1': 0.9785003662109375, 'loss': 0.08822960406541824}
#    Saving to: epoch_98_model.ckpt
# Epoch 99/100
#    -- Batch 1/7 / Loss:  0.073471405
#    -- Batch 2/7 / Loss:  0.081801094
#    -- Batch 3/7 / Loss:  0.07859386
#    -- Batch 4/7 / Loss:  0.07085632
#    -- Batch 5/7 / Loss:  0.069331944
#    -- Batch 6/7 / Loss:  0.0701731
#    -- Batch 7/7 / Loss:  0.069701314
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07341843}
#    Validation: {'f1': 0.9790873527526855, 'loss': 0.08599276095628738}
#    Saving to: epoch_99_model.ckpt
# Epoch 100/100
#    -- Batch 1/7 / Loss:  0.06871102
#    -- Batch 2/7 / Loss:  0.079257146
#    -- Batch 3/7 / Loss:  0.08197171
#    -- Batch 4/7 / Loss:  0.07162486
#    -- Batch 5/7 / Loss:  0.06833632
#    -- Batch 6/7 / Loss:  0.072704166
#    -- Batch 7/7 / Loss:  0.070988856
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.07337058}
#    Validation: {'f1': 0.9777956604957581, 'loss': 0.08788898587226868}
#    Saving to: epoch_100_model.ckpt

# %% [markdown]
# ## Plot training and validation histories

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.savefig("Plot Training and Validation Histories (ELU2)")
plt.show()

# %% [markdown]
# ## Evaluate on single test-set image

# %%
# Predict on a test image
x_test, y_test = test_dataset[0]
if gpu:
  x_test = x_test.to(device)
  y_test = y_test.to(device)
pred = model(x_test.view(1, 1, x_test.shape[1], x_test.shape[2])).argmax(1).cpu().numpy()

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")

plot_image_with_segmentation(x_test.cpu(), y_test.cpu(), ax=ax1)
plot_image_with_segmentation(x_test.cpu(), pred, ax=ax2)

plt.savefig("Evaluation on Single Test-set Image (ELU2)")
plt.show()

# %% [markdown]
# ## Evaluate on whole test-set

# %%
# OBS: Returns batch-wise metrics, but test_loader has batch_size = 1
f1_test_scores = evaluate_model(model, test_loader, metrics, reduction=False)["f1"]

print("Test cases:", len(f1_test_scores))
print("Mean F1:   ", np.mean(f1_test_scores))
print("STD  F1:   ", np.std(f1_test_scores))
print("Min. F1:   ", np.min(f1_test_scores))
# Out:
# Test cases: 123
# Mean F1:    0.9765671045799565
# STD  F1:    0.013334403274847341
# Min. F1:    0.9323980808258057
