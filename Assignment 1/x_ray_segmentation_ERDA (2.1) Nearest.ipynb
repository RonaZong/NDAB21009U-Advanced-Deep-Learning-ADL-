# %% [markdown]
# # U-Net segmentation example
# ### Advanced Deep Learning 2022
# This notebook was originally written by Mathias Perslev. It has been changed slightly by Christian Igel and subsequently slightly updated [Stefan Sommer](mailto:sommer@di.ku.dk).
#
# The U-Net is based on code written by Annika Brundyn and Akshay Kulkarni distributed as part of [*PyTorch Lightning Bolts*](https://pytorch-lightning.readthedocs.io/) under the  [Apache 2.0 license](https://www.apache.org/licenses/LICENSE-2.0.txt).
#
# We consider the data described in:
#
# Bram van Ginneken, Mikkel B. Stegmann, Marco Loog. [Segmentation of anatomical structures in chest radiographs using supervised methods: a comparative study on a public database](https://doi.org/10.1016/j.media.2005.02.002). *Medical Image Analysis* 10(1): 19-40, 2006

# %% [markdown]
# ## Installs
#
# If some packages are missing:

# %%
pip install -q pytorch_lightning lightning-bolts
# Out:
#      |████████████████████████████████| 584 kB 5.0 MB/s
#      |████████████████████████████████| 316 kB 57.7 MB/s
#      |████████████████████████████████| 136 kB 54.9 MB/s
#      |████████████████████████████████| 409 kB 52.6 MB/s
#      |████████████████████████████████| 596 kB 41.5 MB/s
#      |████████████████████████████████| 1.1 MB 44.7 MB/s
#      |████████████████████████████████| 94 kB 917 kB/s
#      |████████████████████████████████| 271 kB 59.9 MB/s
#      |████████████████████████████████| 144 kB 59.4 MB/s

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn as nn
from torch.nn import functional as F
from torchvision.datasets.utils import download_url

import torchmetrics

from pprint import pformat
from skimage.transform import resize
#from sklearn.metrics import f1_score
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

# %% [markdown]
# ## Mount Google drive when using Google Colab

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    os.chdir('gdrive/MyDrive/Colab Notebooks')
except:
    print('Google drive not mounted')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ## Test for GPU support

# %%
# GPU support?
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cpu

# %% [markdown]
# ## U-Net
# Import the U-Net.

# %%
from unet import UNet

# %% [markdown]
# ## Database

# %% [markdown]
# Load database with chest X-rays with lung segmentations.

# %%
data_root='./datasets'
data_npz='lung_field_dataset.npz'
data_fn = os.path.join(data_root, "lung_field_dataset.npz")
force_download = False

if (not os.path.exists(data_fn)) or force_download:
  download_url("https://sid.erda.dk/share_redirect/gCTc6o3KAh", data_root, data_npz)
else:
  print('Using existing', data_fn)
# Out:
# Using existing ./datasets/lung_field_dataset.npz

# %%
def plot_image_with_segmentation(image, segmentation, ax=None):
    """
    Plots an image with overlayed segmentation mask
    
    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")
    
    ax.imshow(image.squeeze(), cmap="gray")
    mask = np.ma.masked_where(segmentation == 0, segmentation)
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax


def load_npz_dataset(path, keys=('x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test')):
    archive = np.load(path)
    return [archive.get(key) for key in keys]

# %%
# Load train/val/test data
x_train, y_train, x_val, y_val, x_test, y_test = load_npz_dataset(data_fn)
# Bring images into PyTorch format
x_train = np.moveaxis(x_train, 3, 1)
y_train = np.moveaxis(y_train, 3, 1)
x_val = np.moveaxis(x_val, 3, 1)
y_val = np.moveaxis(y_val, 3, 1)
x_test = np.moveaxis(x_test, 3, 1)
y_test = np.moveaxis(y_test, 3, 1)

print("x train:", x_train.shape)
print("y train:", y_train.shape)
print("x val: ", x_val.shape)
print("y val: ", y_val.shape)
print("x test:", x_test.shape)
print("y test:", y_test.shape)

# Plot an example
fig, ax = plot_image_with_segmentation(x_train[0], y_train[0])
plt.savefig("Plot Image with Segmentation (2)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-176cd7609234> in <module>()
#       1 # Load train/val/test data
# ----> 2 x_train, y_train, x_val, y_val, x_test, y_test = load_npz_dataset(data_fn)
#       3 # Bring images into PyTorch format
#       4 x_train = np.moveaxis(x_train, 3, 1)
#       5 y_train = np.moveaxis(y_train, 3, 1)
#
# NameError: name 'load_npz_dataset' is not defined

# %% [markdown]
# ### Init torch dataloaders

# %%
def as_torch_dataset(x_arr, y_arr):
    """
    Takes two numpy arrays of data points and labels (x_arr and y_arr, respectively) and
    returns a torch TensorDataset object.
    
    Returns: torch.utils.data.TensorDataset
    """
    dataset = torch.utils.data.TensorDataset(
        torch.FloatTensor(x_arr), 
        torch.LongTensor(y_arr)
    )
    return dataset

# Init torch datasets
train_dataset = as_torch_dataset(x_train, y_train.squeeze(1))  # remove dummy channel dim
val_dataset = as_torch_dataset(x_val, y_val.squeeze(1))
test_dataset = as_torch_dataset(x_test, y_test.squeeze(1))

# Init dataloaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# ### Function for evaluating a model on a data loader

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.
    
    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """
    
    # defaultdict(list) returns a dictionary-like object with default_factory list. 
    # When a new key is encountered, an entry is automatically created of type default_factory. 
    metrics = defaultdict(list)
    with torch.no_grad():
        for batch_x, batch_y in data_loader:
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)
            
            # Compute all metrics
            for metric_name, metric_func in metrics_dict.items():
                value = metric_func(logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                metrics[metric_name].append(value)
    
    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %% [markdown]
# ## Main trainig loop function(s)
#
# We want to track the F1 score during training. This generates some additional code.

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        
        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)
        
        # Compute loss function
        loss_tensor = loss(logits, batch_y)
        loss_scalar = loss_tensor.detach().cpu().numpy()
        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)
        
        # Backprop and step
        loss_tensor.backward()
        optimizer.step()
        
    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model, 
        data_loader=val_loader,
        metrics_dict=metrics_dict
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists
    
    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}
    
    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.
    
    Returns: 
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []
    
    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)
    
    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model, 
                loss=loss, 
                optimizer=optimizer, 
                train_loader=train_loader, 
                val_loader=val_loader, 
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)
            
            if save_path:
                save_path_epoch = f"epoch_{i+1}_{save_path}"
                print(f"   Saving to: {save_path_epoch}")
                save_model(model, save_path_epoch, optimizer)
    except KeyboardInterrupt:
        print("Training stopped.")
        pass
    
    # Merge list of training and validation dicts into single dicts    
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %% [markdown]
# ## Function for plotting training/validation histories

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)
    
    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")
    
    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)
    
    return fig, ax

# %% [markdown]
# ## Functions for saving and loading model and optimizer state

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %% [markdown]
# ## Init U-Net model and optimizer

# %%
# Init U-Net model
model = UNet(
    num_classes=2, 
    input_channels=1, 
    num_layers=4, 
    features_start=16,
)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %% [markdown]
# ## Continue training?

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %% [markdown]
# ## Run training

# %%
# Define loss and metrics
loss = torch.nn.CrossEntropyLoss(reduction="mean")
metrics = {"f1": torchmetrics.classification.F1Score(num_classes=2, average="macro", mdmc_average="samplewise")}

# Run training
train_history, val_history = training_loop(
    model=model,
    loss=loss, 
    optimizer=optimizer, 
    train_loader=train_loader, 
    val_loader=val_loader,
    init_epoch=init_epoch,
    n_epochs=100,
    metrics_dict=metrics,
    save_path="model.ckpt"
)
# Out:
# Epoch 1/100
#    -- Batch 1/7 / Loss:  0.6859719
#    -- Batch 2/7 / Loss:  0.66706514
#    -- Batch 3/7 / Loss:  0.64527535
#    -- Batch 4/7 / Loss:  0.6318097
#    -- Batch 5/7 / Loss:  0.61569774
#    -- Batch 6/7 / Loss:  0.60018903
#    -- Batch 7/7 / Loss:  0.58821034
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.6334599}
#    Validation: {'f1': 0.743396520614624, 'loss': 0.5782771706581116}
#    Saving to: epoch_1_model.ckpt
# Epoch 2/100
#    -- Batch 1/7 / Loss:  0.5777349
#    -- Batch 2/7 / Loss:  0.5739338
#    -- Batch 3/7 / Loss:  0.568553
#    -- Batch 4/7 / Loss:  0.5519107
#    -- Batch 5/7 / Loss:  0.545104
#    -- Batch 6/7 / Loss:  0.5304534
#    -- Batch 7/7 / Loss:  0.5261942
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.553412}
#    Validation: {'f1': 0.7994890213012695, 'loss': 0.5186105370521545}
#    Saving to: epoch_2_model.ckpt
# Epoch 3/100
#    -- Batch 1/7 / Loss:  0.52941626
#    -- Batch 2/7 / Loss:  0.51232684
#    -- Batch 3/7 / Loss:  0.5034927
#    -- Batch 4/7 / Loss:  0.4985011
#    -- Batch 5/7 / Loss:  0.49051243
#    -- Batch 6/7 / Loss:  0.48960203
#    -- Batch 7/7 / Loss:  0.4845316
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.5011976}
#    Validation: {'f1': 0.8194084763526917, 'loss': 0.4724877178668976}
#    Saving to: epoch_3_model.ckpt
# Epoch 4/100
#    -- Batch 1/7 / Loss:  0.4706158
#    -- Batch 2/7 / Loss:  0.4724776
#    -- Batch 3/7 / Loss:  0.4609997
#    -- Batch 4/7 / Loss:  0.45857087
#    -- Batch 5/7 / Loss:  0.45143127
#    -- Batch 6/7 / Loss:  0.4490187
#    -- Batch 7/7 / Loss:  0.44350448
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.45808837}
#    Validation: {'f1': 0.840328574180603, 'loss': 0.4333480894565582}
#    Saving to: epoch_4_model.ckpt
# Epoch 5/100
#    -- Batch 1/7 / Loss:  0.43626556
#    -- Batch 2/7 / Loss:  0.42923805
#    -- Batch 3/7 / Loss:  0.42529133
#    -- Batch 4/7 / Loss:  0.42100084
#    -- Batch 5/7 / Loss:  0.41280872
#    -- Batch 6/7 / Loss:  0.41566983
#    -- Batch 7/7 / Loss:  0.39789113
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.4197379}
#    Validation: {'f1': 0.8760600686073303, 'loss': 0.39595460891723633}
#    Saving to: epoch_5_model.ckpt
# Epoch 6/100
#    -- Batch 1/7 / Loss:  0.39660016
#    -- Batch 2/7 / Loss:  0.3903242
#    -- Batch 3/7 / Loss:  0.38642883
#    -- Batch 4/7 / Loss:  0.3877408
#    -- Batch 5/7 / Loss:  0.38003257
#    -- Batch 6/7 / Loss:  0.3775143
#    -- Batch 7/7 / Loss:  0.3666554
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.38361377}
#    Validation: {'f1': 0.9196139574050903, 'loss': 0.36373206973075867}
#    Saving to: epoch_6_model.ckpt
# Epoch 7/100
#    -- Batch 1/7 / Loss:  0.36389738
#    -- Batch 2/7 / Loss:  0.36554304
#    -- Batch 3/7 / Loss:  0.35360527
#    -- Batch 4/7 / Loss:  0.35198426
#    -- Batch 5/7 / Loss:  0.35206273
#    -- Batch 6/7 / Loss:  0.34307748
#    -- Batch 7/7 / Loss:  0.33853105
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3526716}
#    Validation: {'f1': 0.9441318511962891, 'loss': 0.3384106159210205}
#    Saving to: epoch_7_model.ckpt
# Epoch 8/100
#    -- Batch 1/7 / Loss:  0.33798522
#    -- Batch 2/7 / Loss:  0.33552817
#    -- Batch 3/7 / Loss:  0.33114663
#    -- Batch 4/7 / Loss:  0.32486346
#    -- Batch 5/7 / Loss:  0.33041257
#    -- Batch 6/7 / Loss:  0.32637095
#    -- Batch 7/7 / Loss:  0.32246983
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.32982525}
#    Validation: {'f1': 0.9532129168510437, 'loss': 0.3205718696117401}
#    Saving to: epoch_8_model.ckpt
# Epoch 9/100
#    -- Batch 1/7 / Loss:  0.31892
#    -- Batch 2/7 / Loss:  0.31308421
#    -- Batch 3/7 / Loss:  0.31652907
#    -- Batch 4/7 / Loss:  0.3122454
#    -- Batch 5/7 / Loss:  0.31622094
#    -- Batch 6/7 / Loss:  0.31551704
#    -- Batch 7/7 / Loss:  0.30212376
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.31352004}
#    Validation: {'f1': 0.9589101076126099, 'loss': 0.3065117299556732}
#    Saving to: epoch_9_model.ckpt
# Epoch 10/100
#    -- Batch 1/7 / Loss:  0.30564716
#    -- Batch 2/7 / Loss:  0.30341795
#    -- Batch 3/7 / Loss:  0.30221963
#    -- Batch 4/7 / Loss:  0.29712996
#    -- Batch 5/7 / Loss:  0.2958624
#    -- Batch 6/7 / Loss:  0.3003727
#    -- Batch 7/7 / Loss:  0.295294
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.299992}
#    Validation: {'f1': 0.9619280099868774, 'loss': 0.295578271150589}
#    Saving to: epoch_10_model.ckpt
# Epoch 11/100
#    -- Batch 1/7 / Loss:  0.29342467
#    -- Batch 2/7 / Loss:  0.29267144
#    -- Batch 3/7 / Loss:  0.29195014
#    -- Batch 4/7 / Loss:  0.28909612
#    -- Batch 5/7 / Loss:  0.2873395
#    -- Batch 6/7 / Loss:  0.28701407
#    -- Batch 7/7 / Loss:  0.2843075
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2894005}
#    Validation: {'f1': 0.9643164873123169, 'loss': 0.2862433195114136}
#    Saving to: epoch_11_model.ckpt
# Epoch 12/100
#    -- Batch 1/7 / Loss:  0.2819289
#    -- Batch 2/7 / Loss:  0.28070605
#    -- Batch 3/7 / Loss:  0.27943224
#    -- Batch 4/7 / Loss:  0.28264797
#    -- Batch 5/7 / Loss:  0.28099447
#    -- Batch 6/7 / Loss:  0.2813009
#    -- Batch 7/7 / Loss:  0.27501744
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.28028968}
#    Validation: {'f1': 0.9669346809387207, 'loss': 0.2786761522293091}
#    Saving to: epoch_12_model.ckpt
# Epoch 13/100
#    -- Batch 1/7 / Loss:  0.27705556
#    -- Batch 2/7 / Loss:  0.27631253
#    -- Batch 3/7 / Loss:  0.27232987
#    -- Batch 4/7 / Loss:  0.2770206
#    -- Batch 5/7 / Loss:  0.27307087
#    -- Batch 6/7 / Loss:  0.2708071
#    -- Batch 7/7 / Loss:  0.2684482
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2735778}
#    Validation: {'f1': 0.9672472476959229, 'loss': 0.27354511618614197}
#    Saving to: epoch_13_model.ckpt
# Epoch 14/100
#    -- Batch 1/7 / Loss:  0.27127606
#    -- Batch 2/7 / Loss:  0.27175182
#    -- Batch 3/7 / Loss:  0.27003375
#    -- Batch 4/7 / Loss:  0.26698783
#    -- Batch 5/7 / Loss:  0.27058005
#    -- Batch 6/7 / Loss:  0.26492083
#    -- Batch 7/7 / Loss:  0.26276347
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.26833054}
#    Validation: {'f1': 0.9698176383972168, 'loss': 0.26671361923217773}
#    Saving to: epoch_14_model.ckpt
# Epoch 15/100
#    -- Batch 1/7 / Loss:  0.2702507
#    -- Batch 2/7 / Loss:  0.26302686
#    -- Batch 3/7 / Loss:  0.2627092
#    -- Batch 4/7 / Loss:  0.26183245
#    -- Batch 5/7 / Loss:  0.2598608
#    -- Batch 6/7 / Loss:  0.26331484
#    -- Batch 7/7 / Loss:  0.2611647
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.26316565}
#    Validation: {'f1': 0.9700325131416321, 'loss': 0.2622400224208832}
#    Saving to: epoch_15_model.ckpt
# Epoch 16/100
#    -- Batch 1/7 / Loss:  0.25988287
#    -- Batch 2/7 / Loss:  0.25543684
#    -- Batch 3/7 / Loss:  0.25744253
#    -- Batch 4/7 / Loss:  0.25814638
#    -- Batch 5/7 / Loss:  0.2611917
#    -- Batch 6/7 / Loss:  0.2538296
#    -- Batch 7/7 / Loss:  0.25897872
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2578441}
#    Validation: {'f1': 0.9714134931564331, 'loss': 0.25813883543014526}
#    Saving to: epoch_16_model.ckpt
# Epoch 17/100
#    -- Batch 1/7 / Loss:  0.25354922
#    -- Batch 2/7 / Loss:  0.2539692
#    -- Batch 3/7 / Loss:  0.25650144
#    -- Batch 4/7 / Loss:  0.24984221
#    -- Batch 5/7 / Loss:  0.25287768
#    -- Batch 6/7 / Loss:  0.24849862
#    -- Batch 7/7 / Loss:  0.2563907
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.25308985}
#    Validation: {'f1': 0.9714924097061157, 'loss': 0.25454384088516235}
#    Saving to: epoch_17_model.ckpt
# Epoch 18/100
#    -- Batch 1/7 / Loss:  0.25087863
#    -- Batch 2/7 / Loss:  0.24582504
#    -- Batch 3/7 / Loss:  0.2503105
#    -- Batch 4/7 / Loss:  0.2507201
#    -- Batch 5/7 / Loss:  0.24965723
#    -- Batch 6/7 / Loss:  0.24627064
#    -- Batch 7/7 / Loss:  0.25027087
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2491333}
#    Validation: {'f1': 0.9716763496398926, 'loss': 0.25137701630592346}
#    Saving to: epoch_18_model.ckpt
# Epoch 19/100
#    -- Batch 1/7 / Loss:  0.24732567
#    -- Batch 2/7 / Loss:  0.24878284
#    -- Batch 3/7 / Loss:  0.241668
#    -- Batch 4/7 / Loss:  0.2526349
#    -- Batch 5/7 / Loss:  0.24304983
#    -- Batch 6/7 / Loss:  0.24310002
#    -- Batch 7/7 / Loss:  0.24474879
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24590145}
#    Validation: {'f1': 0.9718151688575745, 'loss': 0.2477424591779709}
#    Saving to: epoch_19_model.ckpt
# Epoch 20/100
#    -- Batch 1/7 / Loss:  0.24469905
#    -- Batch 2/7 / Loss:  0.23993623
#    -- Batch 3/7 / Loss:  0.24552512
#    -- Batch 4/7 / Loss:  0.24620667
#    -- Batch 5/7 / Loss:  0.24268535
#    -- Batch 6/7 / Loss:  0.23844661
#    -- Batch 7/7 / Loss:  0.24090348
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24262893}
#    Validation: {'f1': 0.9731519222259521, 'loss': 0.2434573620557785}
#    Saving to: epoch_20_model.ckpt
# Epoch 21/100
#    -- Batch 1/7 / Loss:  0.23718919
#    -- Batch 2/7 / Loss:  0.24230926
#    -- Batch 3/7 / Loss:  0.23697127
#    -- Batch 4/7 / Loss:  0.23593098
#    -- Batch 5/7 / Loss:  0.24362047
#    -- Batch 6/7 / Loss:  0.23948002
#    -- Batch 7/7 / Loss:  0.23901835
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23921707}
#    Validation: {'f1': 0.9718878269195557, 'loss': 0.24254930019378662}
#    Saving to: epoch_21_model.ckpt
# Epoch 22/100
#    -- Batch 1/7 / Loss:  0.23460692
#    -- Batch 2/7 / Loss:  0.24198027
#    -- Batch 3/7 / Loss:  0.24623685
#    -- Batch 4/7 / Loss:  0.2338696
#    -- Batch 5/7 / Loss:  0.2332058
#    -- Batch 6/7 / Loss:  0.23218623
#    -- Batch 7/7 / Loss:  0.23540252
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23678401}
#    Validation: {'f1': 0.9728972315788269, 'loss': 0.2378469556570053}
#    Saving to: epoch_22_model.ckpt
# Epoch 23/100
#    -- Batch 1/7 / Loss:  0.235273
#    -- Batch 2/7 / Loss:  0.22868767
#    -- Batch 3/7 / Loss:  0.23539728
#    -- Batch 4/7 / Loss:  0.23162124
#    -- Batch 5/7 / Loss:  0.23512791
#    -- Batch 6/7 / Loss:  0.23513812
#    -- Batch 7/7 / Loss:  0.2267481
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2325705}
#    Validation: {'f1': 0.9726052284240723, 'loss': 0.23604004085063934}
#    Saving to: epoch_23_model.ckpt
# Epoch 24/100
#    -- Batch 1/7 / Loss:  0.23043548
#    -- Batch 2/7 / Loss:  0.2325937
#    -- Batch 3/7 / Loss:  0.23410578
#    -- Batch 4/7 / Loss:  0.22994944
#    -- Batch 5/7 / Loss:  0.22434811
#    -- Batch 6/7 / Loss:  0.22502604
#    -- Batch 7/7 / Loss:  0.22822347
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22924028}
#    Validation: {'f1': 0.973697304725647, 'loss': 0.232646644115448}
#    Saving to: epoch_24_model.ckpt
# Epoch 25/100
#    -- Batch 1/7 / Loss:  0.22902781
#    -- Batch 2/7 / Loss:  0.22639558
#    -- Batch 3/7 / Loss:  0.22268541
#    -- Batch 4/7 / Loss:  0.22259398
#    -- Batch 5/7 / Loss:  0.2270133
#    -- Batch 6/7 / Loss:  0.22820662
#    -- Batch 7/7 / Loss:  0.22160374
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22536092}
#    Validation: {'f1': 0.9742188453674316, 'loss': 0.22936998307704926}
#    Saving to: epoch_25_model.ckpt
# Epoch 26/100
#    -- Batch 1/7 / Loss:  0.22414114
#    -- Batch 2/7 / Loss:  0.21994781
#    -- Batch 3/7 / Loss:  0.22179192
#    -- Batch 4/7 / Loss:  0.22188358
#    -- Batch 5/7 / Loss:  0.22335593
#    -- Batch 6/7 / Loss:  0.22745492
#    -- Batch 7/7 / Loss:  0.21930736
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22255465}
#    Validation: {'f1': 0.971476674079895, 'loss': 0.22896577417850494}
#    Saving to: epoch_26_model.ckpt
# Epoch 27/100
#    -- Batch 1/7 / Loss:  0.22098546
#    -- Batch 2/7 / Loss:  0.2205869
#    -- Batch 3/7 / Loss:  0.2145185
#    -- Batch 4/7 / Loss:  0.22644344
#    -- Batch 5/7 / Loss:  0.21705271
#    -- Batch 6/7 / Loss:  0.22052102
#    -- Batch 7/7 / Loss:  0.21775287
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2196944}
#    Validation: {'f1': 0.9736982583999634, 'loss': 0.22346018254756927}
#    Saving to: epoch_27_model.ckpt
# Epoch 28/100
#    -- Batch 1/7 / Loss:  0.21632756
#    -- Batch 2/7 / Loss:  0.21630085
#    -- Batch 3/7 / Loss:  0.21818589
#    -- Batch 4/7 / Loss:  0.21587442
#    -- Batch 5/7 / Loss:  0.21285808
#    -- Batch 6/7 / Loss:  0.21461505
#    -- Batch 7/7 / Loss:  0.2161721
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21576199}
#    Validation: {'f1': 0.9740651249885559, 'loss': 0.22036327421665192}
#    Saving to: epoch_28_model.ckpt
# Epoch 29/100
#    -- Batch 1/7 / Loss:  0.2146886
#    -- Batch 2/7 / Loss:  0.21012948
#    -- Batch 3/7 / Loss:  0.21307634
#    -- Batch 4/7 / Loss:  0.21429843
#    -- Batch 5/7 / Loss:  0.20877405
#    -- Batch 6/7 / Loss:  0.21940964
#    -- Batch 7/7 / Loss:  0.20988236
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21289416}
#    Validation: {'f1': 0.9740270972251892, 'loss': 0.21760272979736328}
#    Saving to: epoch_29_model.ckpt
# Epoch 30/100
#    -- Batch 1/7 / Loss:  0.21369971
#    -- Batch 2/7 / Loss:  0.2085363
#    -- Batch 3/7 / Loss:  0.21509197
#    -- Batch 4/7 / Loss:  0.20684768
#    -- Batch 5/7 / Loss:  0.2069044
#    -- Batch 6/7 / Loss:  0.2090447
#    -- Batch 7/7 / Loss:  0.20733154
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20963661}
#    Validation: {'f1': 0.9748139381408691, 'loss': 0.21416504681110382}
#    Saving to: epoch_30_model.ckpt
# Epoch 31/100
#    -- Batch 1/7 / Loss:  0.20471326
#    -- Batch 2/7 / Loss:  0.2096614
#    -- Batch 3/7 / Loss:  0.21029188
#    -- Batch 4/7 / Loss:  0.20652984
#    -- Batch 5/7 / Loss:  0.20501563
#    -- Batch 6/7 / Loss:  0.20543745
#    -- Batch 7/7 / Loss:  0.20497909
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20666121}
#    Validation: {'f1': 0.975199818611145, 'loss': 0.21181821823120117}
#    Saving to: epoch_31_model.ckpt
# Epoch 32/100
#    -- Batch 1/7 / Loss:  0.20179257
#    -- Batch 2/7 / Loss:  0.20158921
#    -- Batch 3/7 / Loss:  0.20166907
#    -- Batch 4/7 / Loss:  0.20468153
#    -- Batch 5/7 / Loss:  0.20460492
#    -- Batch 6/7 / Loss:  0.20602395
#    -- Batch 7/7 / Loss:  0.21035428
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20438793}
#    Validation: {'f1': 0.9742428064346313, 'loss': 0.21126633882522583}
#    Saving to: epoch_32_model.ckpt
# Epoch 33/100
#    -- Batch 1/7 / Loss:  0.20980024
#    -- Batch 2/7 / Loss:  0.20346832
#    -- Batch 3/7 / Loss:  0.20019282
#    -- Batch 4/7 / Loss:  0.20053564
#    -- Batch 5/7 / Loss:  0.2022589
#    -- Batch 6/7 / Loss:  0.20140237
#    -- Batch 7/7 / Loss:  0.1988105
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20235267}
#    Validation: {'f1': 0.9739423394203186, 'loss': 0.2087814062833786}
#    Saving to: epoch_33_model.ckpt
# Epoch 34/100
#    -- Batch 1/7 / Loss:  0.20309287
#    -- Batch 2/7 / Loss:  0.19677863
#    -- Batch 3/7 / Loss:  0.19775414
#    -- Batch 4/7 / Loss:  0.20023681
#    -- Batch 5/7 / Loss:  0.19854201
#    -- Batch 6/7 / Loss:  0.202231
#    -- Batch 7/7 / Loss:  0.1959292
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19922352}
#    Validation: {'f1': 0.975448489189148, 'loss': 0.20527206361293793}
#    Saving to: epoch_34_model.ckpt
# Epoch 35/100
#    -- Batch 1/7 / Loss:  0.19583368
#    -- Batch 2/7 / Loss:  0.19740504
#    -- Batch 3/7 / Loss:  0.19783726
#    -- Batch 4/7 / Loss:  0.19675644
#    -- Batch 5/7 / Loss:  0.1960613
#    -- Batch 6/7 / Loss:  0.19962358
#    -- Batch 7/7 / Loss:  0.1936478
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19673787}
#    Validation: {'f1': 0.9756845235824585, 'loss': 0.20326244831085205}
#    Saving to: epoch_35_model.ckpt
# Epoch 36/100
#    -- Batch 1/7 / Loss:  0.1947951
#    -- Batch 2/7 / Loss:  0.19245286
#    -- Batch 3/7 / Loss:  0.19373801
#    -- Batch 4/7 / Loss:  0.19398338
#    -- Batch 5/7 / Loss:  0.19913822
#    -- Batch 6/7 / Loss:  0.19304495
#    -- Batch 7/7 / Loss:  0.19436008
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1945018}
#    Validation: {'f1': 0.9739729166030884, 'loss': 0.20340721309185028}
#    Saving to: epoch_36_model.ckpt
# Epoch 37/100
#    -- Batch 1/7 / Loss:  0.19116192
#    -- Batch 2/7 / Loss:  0.1901219
#    -- Batch 3/7 / Loss:  0.19646327
#    -- Batch 4/7 / Loss:  0.19096524
#    -- Batch 5/7 / Loss:  0.19745333
#    -- Batch 6/7 / Loss:  0.191969
#    -- Batch 7/7 / Loss:  0.19220825
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19290614}
#    Validation: {'f1': 0.9736014008522034, 'loss': 0.20173411071300507}
#    Saving to: epoch_37_model.ckpt
# Epoch 38/100
#    -- Batch 1/7 / Loss:  0.19638905
#    -- Batch 2/7 / Loss:  0.19244659
#    -- Batch 3/7 / Loss:  0.19263615
#    -- Batch 4/7 / Loss:  0.18746309
#    -- Batch 5/7 / Loss:  0.19263324
#    -- Batch 6/7 / Loss:  0.18957576
#    -- Batch 7/7 / Loss:  0.18467742
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19083163}
#    Validation: {'f1': 0.9754222631454468, 'loss': 0.1977088451385498}
#    Saving to: epoch_38_model.ckpt
# Epoch 39/100
#    -- Batch 1/7 / Loss:  0.18906477
#    -- Batch 2/7 / Loss:  0.18943186
#    -- Batch 3/7 / Loss:  0.19349098
#    -- Batch 4/7 / Loss:  0.18642884
#    -- Batch 5/7 / Loss:  0.18548794
#    -- Batch 6/7 / Loss:  0.18719158
#    -- Batch 7/7 / Loss:  0.19318505
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18918301}
#    Validation: {'f1': 0.975307822227478, 'loss': 0.19519297778606415}
#    Saving to: epoch_39_model.ckpt
# Epoch 40/100
#    -- Batch 1/7 / Loss:  0.18751757
#    -- Batch 2/7 / Loss:  0.18635964
#    -- Batch 3/7 / Loss:  0.18337208
#    -- Batch 4/7 / Loss:  0.18727624
#    -- Batch 5/7 / Loss:  0.18620737
#    -- Batch 6/7 / Loss:  0.18710318
#    -- Batch 7/7 / Loss:  0.18417971
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18600225}
#    Validation: {'f1': 0.9750982522964478, 'loss': 0.19446618854999542}
#    Saving to: epoch_40_model.ckpt
# Epoch 41/100
#    -- Batch 1/7 / Loss:  0.18074924
#    -- Batch 2/7 / Loss:  0.1820535
#    -- Batch 3/7 / Loss:  0.18574388
#    -- Batch 4/7 / Loss:  0.18602018
#    -- Batch 5/7 / Loss:  0.18527575
#    -- Batch 6/7 / Loss:  0.18616201
#    -- Batch 7/7 / Loss:  0.18613066
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18459074}
#    Validation: {'f1': 0.9753991365432739, 'loss': 0.1930703967809677}
#    Saving to: epoch_41_model.ckpt
# Epoch 42/100
#    -- Batch 1/7 / Loss:  0.18025133
#    -- Batch 2/7 / Loss:  0.18288049
#    -- Batch 3/7 / Loss:  0.18404022
#    -- Batch 4/7 / Loss:  0.18563677
#    -- Batch 5/7 / Loss:  0.1786428
#    -- Batch 6/7 / Loss:  0.17910726
#    -- Batch 7/7 / Loss:  0.18485221
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1822016}
#    Validation: {'f1': 0.9756405353546143, 'loss': 0.19060832262039185}
#    Saving to: epoch_42_model.ckpt
# Epoch 43/100
#    -- Batch 1/7 / Loss:  0.1877356
#    -- Batch 2/7 / Loss:  0.18224694
#    -- Batch 3/7 / Loss:  0.18225163
#    -- Batch 4/7 / Loss:  0.1748421
#    -- Batch 5/7 / Loss:  0.17999622
#    -- Batch 6/7 / Loss:  0.18039888
#    -- Batch 7/7 / Loss:  0.17891209
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18091193}
#    Validation: {'f1': 0.9765605926513672, 'loss': 0.18749380111694336}
#    Saving to: epoch_43_model.ckpt
# Epoch 44/100
#    -- Batch 1/7 / Loss:  0.176192
#    -- Batch 2/7 / Loss:  0.18309957
#    -- Batch 3/7 / Loss:  0.17851704
#    -- Batch 4/7 / Loss:  0.17814809
#    -- Batch 5/7 / Loss:  0.17777337
#    -- Batch 6/7 / Loss:  0.18283775
#    -- Batch 7/7 / Loss:  0.17425935
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17868958}
#    Validation: {'f1': 0.9756201505661011, 'loss': 0.18717576563358307}
#    Saving to: epoch_44_model.ckpt
# Epoch 45/100
#    -- Batch 1/7 / Loss:  0.17673808
#    -- Batch 2/7 / Loss:  0.17650715
#    -- Batch 3/7 / Loss:  0.17680164
#    -- Batch 4/7 / Loss:  0.17739278
#    -- Batch 5/7 / Loss:  0.17662045
#    -- Batch 6/7 / Loss:  0.17504597
#    -- Batch 7/7 / Loss:  0.17483227
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1762769}
#    Validation: {'f1': 0.9752727746963501, 'loss': 0.18636129796504974}
#    Saving to: epoch_45_model.ckpt
# Epoch 46/100
#    -- Batch 1/7 / Loss:  0.17402218
#    -- Batch 2/7 / Loss:  0.17428508
#    -- Batch 3/7 / Loss:  0.17500612
#    -- Batch 4/7 / Loss:  0.17493445
#    -- Batch 5/7 / Loss:  0.17302404
#    -- Batch 6/7 / Loss:  0.17669849
#    -- Batch 7/7 / Loss:  0.17167841
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17423555}
#    Validation: {'f1': 0.9750186800956726, 'loss': 0.18512678146362305}
#    Saving to: epoch_46_model.ckpt
# Epoch 47/100
#    -- Batch 1/7 / Loss:  0.17566533
#    -- Batch 2/7 / Loss:  0.17255348
#    -- Batch 3/7 / Loss:  0.17353262
#    -- Batch 4/7 / Loss:  0.18270026
#    -- Batch 5/7 / Loss:  0.17290816
#    -- Batch 6/7 / Loss:  0.17191845
#    -- Batch 7/7 / Loss:  0.16838688
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17395218}
#    Validation: {'f1': 0.9761722087860107, 'loss': 0.18154169619083405}
#    Saving to: epoch_47_model.ckpt
# Epoch 48/100
#    -- Batch 1/7 / Loss:  0.17117229
#    -- Batch 2/7 / Loss:  0.16638726
#    -- Batch 3/7 / Loss:  0.18348183
#    -- Batch 4/7 / Loss:  0.16823521
#    -- Batch 5/7 / Loss:  0.1677037
#    -- Batch 6/7 / Loss:  0.1738727
#    -- Batch 7/7 / Loss:  0.17059596
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17163555}
#    Validation: {'f1': 0.9753897190093994, 'loss': 0.18099434673786163}
#    Saving to: epoch_48_model.ckpt
# Epoch 49/100
#    -- Batch 1/7 / Loss:  0.17059931
#    -- Batch 2/7 / Loss:  0.16929467
#    -- Batch 3/7 / Loss:  0.16693419
#    -- Batch 4/7 / Loss:  0.17107646
#    -- Batch 5/7 / Loss:  0.16965187
#    -- Batch 6/7 / Loss:  0.1691582
#    -- Batch 7/7 / Loss:  0.16465949
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16876774}
#    Validation: {'f1': 0.9764633178710938, 'loss': 0.1785399466753006}
#    Saving to: epoch_49_model.ckpt
# Epoch 50/100
#    -- Batch 1/7 / Loss:  0.16790609
#    -- Batch 2/7 / Loss:  0.16504265
#    -- Batch 3/7 / Loss:  0.1663856
#    -- Batch 4/7 / Loss:  0.16754325
#    -- Batch 5/7 / Loss:  0.16924615
#    -- Batch 6/7 / Loss:  0.16383156
#    -- Batch 7/7 / Loss:  0.16753429
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16678421}
#    Validation: {'f1': 0.9765880703926086, 'loss': 0.17681701481342316}
#    Saving to: epoch_50_model.ckpt
# Epoch 51/100
#    -- Batch 1/7 / Loss:  0.16848381
#    -- Batch 2/7 / Loss:  0.16044769
#    -- Batch 3/7 / Loss:  0.16696821
#    -- Batch 4/7 / Loss:  0.16201638
#    -- Batch 5/7 / Loss:  0.169237
#    -- Batch 6/7 / Loss:  0.1677097
#    -- Batch 7/7 / Loss:  0.165701
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16579483}
#    Validation: {'f1': 0.9758274555206299, 'loss': 0.17622686922550201}
#    Saving to: epoch_51_model.ckpt
# Epoch 52/100
#    -- Batch 1/7 / Loss:  0.16398184
#    -- Batch 2/7 / Loss:  0.15869941
#    -- Batch 3/7 / Loss:  0.16784969
#    -- Batch 4/7 / Loss:  0.16548991
#    -- Batch 5/7 / Loss:  0.15997393
#    -- Batch 6/7 / Loss:  0.16910836
#    -- Batch 7/7 / Loss:  0.16109562
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16374268}
#    Validation: {'f1': 0.9754031300544739, 'loss': 0.17517012357711792}
#    Saving to: epoch_52_model.ckpt
# Epoch 53/100
#    -- Batch 1/7 / Loss:  0.15997933
#    -- Batch 2/7 / Loss:  0.16100912
#    -- Batch 3/7 / Loss:  0.16581643
#    -- Batch 4/7 / Loss:  0.16181654
#    -- Batch 5/7 / Loss:  0.16569361
#    -- Batch 6/7 / Loss:  0.16250338
#    -- Batch 7/7 / Loss:  0.1586381
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16220808}
#    Validation: {'f1': 0.975469172000885, 'loss': 0.1742061972618103}
#    Saving to: epoch_53_model.ckpt
# Epoch 54/100
#    -- Batch 1/7 / Loss:  0.16228092
#    -- Batch 2/7 / Loss:  0.157517
#    -- Batch 3/7 / Loss:  0.16196842
#    -- Batch 4/7 / Loss:  0.16161945
#    -- Batch 5/7 / Loss:  0.1604862
#    -- Batch 6/7 / Loss:  0.15577917
#    -- Batch 7/7 / Loss:  0.16167872
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16018999}
#    Validation: {'f1': 0.9761226177215576, 'loss': 0.17163294553756714}
#    Saving to: epoch_54_model.ckpt
# Epoch 55/100
#    -- Batch 1/7 / Loss:  0.16034459
#    -- Batch 2/7 / Loss:  0.16078857
#    -- Batch 3/7 / Loss:  0.15595607
#    -- Batch 4/7 / Loss:  0.15884519
#    -- Batch 5/7 / Loss:  0.15961073
#    -- Batch 6/7 / Loss:  0.15323454
#    -- Batch 7/7 / Loss:  0.15986964
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15837848}
#    Validation: {'f1': 0.9761340618133545, 'loss': 0.16998757421970367}
#    Saving to: epoch_55_model.ckpt
# Epoch 56/100
#    -- Batch 1/7 / Loss:  0.16156349
#    -- Batch 2/7 / Loss:  0.16154736
#    -- Batch 3/7 / Loss:  0.15513586
#    -- Batch 4/7 / Loss:  0.15467991
#    -- Batch 5/7 / Loss:  0.1553493
#    -- Batch 6/7 / Loss:  0.1570077
#    -- Batch 7/7 / Loss:  0.15634677
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15737577}
#    Validation: {'f1': 0.9761227369308472, 'loss': 0.16861315071582794}
#    Saving to: epoch_56_model.ckpt
# Epoch 57/100
#    -- Batch 1/7 / Loss:  0.15335414
#    -- Batch 2/7 / Loss:  0.16087815
#    -- Batch 3/7 / Loss:  0.15294117
#    -- Batch 4/7 / Loss:  0.15681681
#    -- Batch 5/7 / Loss:  0.15405571
#    -- Batch 6/7 / Loss:  0.1555624
#    -- Batch 7/7 / Loss:  0.1536834
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15532741}
#    Validation: {'f1': 0.9759174585342407, 'loss': 0.16764335334300995}
#    Saving to: epoch_57_model.ckpt
# Epoch 58/100
#    -- Batch 1/7 / Loss:  0.15443413
#    -- Batch 2/7 / Loss:  0.15618823
#    -- Batch 3/7 / Loss:  0.1570859
#    -- Batch 4/7 / Loss:  0.15543097
#    -- Batch 5/7 / Loss:  0.15313585
#    -- Batch 6/7 / Loss:  0.15321793
#    -- Batch 7/7 / Loss:  0.15186186
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15447927}
#    Validation: {'f1': 0.9756326675415039, 'loss': 0.16636259853839874}
#    Saving to: epoch_58_model.ckpt
# Epoch 59/100
#    -- Batch 1/7 / Loss:  0.15042786
#    -- Batch 2/7 / Loss:  0.15784816
#    -- Batch 3/7 / Loss:  0.15143289
#    -- Batch 4/7 / Loss:  0.15261506
#    -- Batch 5/7 / Loss:  0.16137806
#    -- Batch 6/7 / Loss:  0.15255374
#    -- Batch 7/7 / Loss:  0.15106365
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15390277}
#    Validation: {'f1': 0.9755451679229736, 'loss': 0.16606220602989197}
#    Saving to: epoch_59_model.ckpt
# Epoch 60/100
#    -- Batch 1/7 / Loss:  0.15035018
#    -- Batch 2/7 / Loss:  0.15457107
#    -- Batch 3/7 / Loss:  0.16107441
#    -- Batch 4/7 / Loss:  0.14977157
#    -- Batch 5/7 / Loss:  0.15143758
#    -- Batch 6/7 / Loss:  0.14829831
#    -- Batch 7/7 / Loss:  0.14758657
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15186997}
#    Validation: {'f1': 0.9756768941879272, 'loss': 0.16431598365306854}
#    Saving to: epoch_60_model.ckpt
# Epoch 61/100
#    -- Batch 1/7 / Loss:  0.15415455
#    -- Batch 2/7 / Loss:  0.15137868
#    -- Batch 3/7 / Loss:  0.14748754
#    -- Batch 4/7 / Loss:  0.14899608
#    -- Batch 5/7 / Loss:  0.14915276
#    -- Batch 6/7 / Loss:  0.14620574
#    -- Batch 7/7 / Loss:  0.1505802
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14970793}
#    Validation: {'f1': 0.9765695333480835, 'loss': 0.16172948479652405}
#    Saving to: epoch_61_model.ckpt
# Epoch 62/100
#    -- Batch 1/7 / Loss:  0.14992085
#    -- Batch 2/7 / Loss:  0.15201469
#    -- Batch 3/7 / Loss:  0.14896746
#    -- Batch 4/7 / Loss:  0.15002851
#    -- Batch 5/7 / Loss:  0.14719611
#    -- Batch 6/7 / Loss:  0.14442961
#    -- Batch 7/7 / Loss:  0.14380947
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14805238}
#    Validation: {'f1': 0.9760146141052246, 'loss': 0.16111505031585693}
#    Saving to: epoch_62_model.ckpt
# Epoch 63/100
#    -- Batch 1/7 / Loss:  0.14824776
#    -- Batch 2/7 / Loss:  0.14391297
#    -- Batch 3/7 / Loss:  0.14787193
#    -- Batch 4/7 / Loss:  0.14256509
#    -- Batch 5/7 / Loss:  0.14461684
#    -- Batch 6/7 / Loss:  0.14642543
#    -- Batch 7/7 / Loss:  0.15398276
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14680324}
#    Validation: {'f1': 0.9759006500244141, 'loss': 0.16023598611354828}
#    Saving to: epoch_63_model.ckpt
# Epoch 64/100
#    -- Batch 1/7 / Loss:  0.14713289
#    -- Batch 2/7 / Loss:  0.14569092
#    -- Batch 3/7 / Loss:  0.14095268
#    -- Batch 4/7 / Loss:  0.15047532
#    -- Batch 5/7 / Loss:  0.14480573
#    -- Batch 6/7 / Loss:  0.14205457
#    -- Batch 7/7 / Loss:  0.1452491
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14519444}
#    Validation: {'f1': 0.9755948185920715, 'loss': 0.15994171798229218}
#    Saving to: epoch_64_model.ckpt
# Epoch 65/100
#    -- Batch 1/7 / Loss:  0.15026513
#    -- Batch 2/7 / Loss:  0.14245602
#    -- Batch 3/7 / Loss:  0.14526907
#    -- Batch 4/7 / Loss:  0.14183943
#    -- Batch 5/7 / Loss:  0.14156084
#    -- Batch 6/7 / Loss:  0.1437904
#    -- Batch 7/7 / Loss:  0.140998
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14373983}
#    Validation: {'f1': 0.9761265516281128, 'loss': 0.15790873765945435}
#    Saving to: epoch_65_model.ckpt
# Epoch 66/100
#    -- Batch 1/7 / Loss:  0.1439191
#    -- Batch 2/7 / Loss:  0.14013545
#    -- Batch 3/7 / Loss:  0.14388828
#    -- Batch 4/7 / Loss:  0.14183666
#    -- Batch 5/7 / Loss:  0.14348067
#    -- Batch 6/7 / Loss:  0.14488281
#    -- Batch 7/7 / Loss:  0.13710041
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14217761}
#    Validation: {'f1': 0.9770776033401489, 'loss': 0.15582725405693054}
#    Saving to: epoch_66_model.ckpt
# Epoch 67/100
#    -- Batch 1/7 / Loss:  0.13927937
#    -- Batch 2/7 / Loss:  0.1464982
#    -- Batch 3/7 / Loss:  0.13912705
#    -- Batch 4/7 / Loss:  0.14440425
#    -- Batch 5/7 / Loss:  0.13960445
#    -- Batch 6/7 / Loss:  0.14230561
#    -- Batch 7/7 / Loss:  0.1372787
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14121394}
#    Validation: {'f1': 0.9767404794692993, 'loss': 0.15456753969192505}
#    Saving to: epoch_67_model.ckpt
# Epoch 68/100
#    -- Batch 1/7 / Loss:  0.13909963
#    -- Batch 2/7 / Loss:  0.13999183
#    -- Batch 3/7 / Loss:  0.14012413
#    -- Batch 4/7 / Loss:  0.13762268
#    -- Batch 5/7 / Loss:  0.14232041
#    -- Batch 6/7 / Loss:  0.13740298
#    -- Batch 7/7 / Loss:  0.13855144
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13930188}
#    Validation: {'f1': 0.9760717153549194, 'loss': 0.15463976562023163}
#    Saving to: epoch_68_model.ckpt
# Epoch 69/100
#    -- Batch 1/7 / Loss:  0.14089848
#    -- Batch 2/7 / Loss:  0.13801001
#    -- Batch 3/7 / Loss:  0.14105275
#    -- Batch 4/7 / Loss:  0.14031073
#    -- Batch 5/7 / Loss:  0.13716182
#    -- Batch 6/7 / Loss:  0.1352279
#    -- Batch 7/7 / Loss:  0.13389322
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13807929}
#    Validation: {'f1': 0.9764509201049805, 'loss': 0.15272852778434753}
#    Saving to: epoch_69_model.ckpt
# Epoch 70/100
#    -- Batch 1/7 / Loss:  0.13326338
#    -- Batch 2/7 / Loss:  0.14150065
#    -- Batch 3/7 / Loss:  0.13589473
#    -- Batch 4/7 / Loss:  0.13744026
#    -- Batch 5/7 / Loss:  0.13856688
#    -- Batch 6/7 / Loss:  0.1352799
#    -- Batch 7/7 / Loss:  0.13563065
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13679664}
#    Validation: {'f1': 0.9757976531982422, 'loss': 0.15235623717308044}
#    Saving to: epoch_70_model.ckpt
# Epoch 71/100
#    -- Batch 1/7 / Loss:  0.13751766
#    -- Batch 2/7 / Loss:  0.13758032
#    -- Batch 3/7 / Loss:  0.1318385
#    -- Batch 4/7 / Loss:  0.14065884
#    -- Batch 5/7 / Loss:  0.1322367
#    -- Batch 6/7 / Loss:  0.13245566
#    -- Batch 7/7 / Loss:  0.13725786
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13564937}
#    Validation: {'f1': 0.9766698479652405, 'loss': 0.1505080908536911}
#    Saving to: epoch_71_model.ckpt
# Epoch 72/100
#    -- Batch 1/7 / Loss:  0.13027808
#    -- Batch 2/7 / Loss:  0.13302778
#    -- Batch 3/7 / Loss:  0.13280545
#    -- Batch 4/7 / Loss:  0.13660263
#    -- Batch 5/7 / Loss:  0.13100493
#    -- Batch 6/7 / Loss:  0.13848864
#    -- Batch 7/7 / Loss:  0.13642707
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13409066}
#    Validation: {'f1': 0.975945770740509, 'loss': 0.15091997385025024}
#    Saving to: epoch_72_model.ckpt
# Epoch 73/100
#    -- Batch 1/7 / Loss:  0.13325128
#    -- Batch 2/7 / Loss:  0.13185872
#    -- Batch 3/7 / Loss:  0.13185208
#    -- Batch 4/7 / Loss:  0.13512884
#    -- Batch 5/7 / Loss:  0.13707589
#    -- Batch 6/7 / Loss:  0.12883228
#    -- Batch 7/7 / Loss:  0.13116083
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13273714}
#    Validation: {'f1': 0.976047158241272, 'loss': 0.14894793927669525}
#    Saving to: epoch_73_model.ckpt
# Epoch 74/100
#    -- Batch 1/7 / Loss:  0.12842256
#    -- Batch 2/7 / Loss:  0.13002443
#    -- Batch 3/7 / Loss:  0.13485436
#    -- Batch 4/7 / Loss:  0.12741357
#    -- Batch 5/7 / Loss:  0.13208999
#    -- Batch 6/7 / Loss:  0.13328761
#    -- Batch 7/7 / Loss:  0.13432127
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13148768}
#    Validation: {'f1': 0.9746280908584595, 'loss': 0.1500193029642105}
#    Saving to: epoch_74_model.ckpt
# Epoch 75/100
#    -- Batch 1/7 / Loss:  0.13031168
#    -- Batch 2/7 / Loss:  0.13357346
#    -- Batch 3/7 / Loss:  0.13716696
#    -- Batch 4/7 / Loss:  0.1270152
#    -- Batch 5/7 / Loss:  0.1343208
#    -- Batch 6/7 / Loss:  0.12797092
#    -- Batch 7/7 / Loss:  0.12595831
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13090248}
#    Validation: {'f1': 0.9764454364776611, 'loss': 0.14654593169689178}
#    Saving to: epoch_75_model.ckpt
# Epoch 76/100
#    -- Batch 1/7 / Loss:  0.13391533
#    -- Batch 2/7 / Loss:  0.1274701
#    -- Batch 3/7 / Loss:  0.1289582
#    -- Batch 4/7 / Loss:  0.12643614
#    -- Batch 5/7 / Loss:  0.13087541
#    -- Batch 6/7 / Loss:  0.12715998
#    -- Batch 7/7 / Loss:  0.1258696
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12866926}
#    Validation: {'f1': 0.9764823913574219, 'loss': 0.14562635123729706}
#    Saving to: epoch_76_model.ckpt
# Epoch 77/100
#    -- Batch 1/7 / Loss:  0.13262717
#    -- Batch 2/7 / Loss:  0.1257111
#    -- Batch 3/7 / Loss:  0.1268891
#    -- Batch 4/7 / Loss:  0.12514597
#    -- Batch 5/7 / Loss:  0.12814291
#    -- Batch 6/7 / Loss:  0.123847194
#    -- Batch 7/7 / Loss:  0.13099182
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12762217}
#    Validation: {'f1': 0.9759200811386108, 'loss': 0.14509719610214233}
#    Saving to: epoch_77_model.ckpt
# Epoch 78/100
#    -- Batch 1/7 / Loss:  0.12712397
#    -- Batch 2/7 / Loss:  0.12836157
#    -- Batch 3/7 / Loss:  0.123911075
#    -- Batch 4/7 / Loss:  0.12640429
#    -- Batch 5/7 / Loss:  0.12275948
#    -- Batch 6/7 / Loss:  0.13245307
#    -- Batch 7/7 / Loss:  0.12428731
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12647153}
#    Validation: {'f1': 0.9759575128555298, 'loss': 0.14444415271282196}
#    Saving to: epoch_78_model.ckpt
# Epoch 79/100
#    -- Batch 1/7 / Loss:  0.12694892
#    -- Batch 2/7 / Loss:  0.123654075
#    -- Batch 3/7 / Loss:  0.12386103
#    -- Batch 4/7 / Loss:  0.12903596
#    -- Batch 5/7 / Loss:  0.12326959
#    -- Batch 6/7 / Loss:  0.12542184
#    -- Batch 7/7 / Loss:  0.12220754
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.124914125}
#    Validation: {'f1': 0.9765068292617798, 'loss': 0.14245294034481049}
#    Saving to: epoch_79_model.ckpt
# Epoch 80/100
#    -- Batch 1/7 / Loss:  0.12873058
#    -- Batch 2/7 / Loss:  0.124358065
#    -- Batch 3/7 / Loss:  0.12126902
#    -- Batch 4/7 / Loss:  0.121282406
#    -- Batch 5/7 / Loss:  0.12883885
#    -- Batch 6/7 / Loss:  0.123514816
#    -- Batch 7/7 / Loss:  0.12001983
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12400194}
#    Validation: {'f1': 0.9762871265411377, 'loss': 0.14207430183887482}
#    Saving to: epoch_80_model.ckpt
# Epoch 81/100
#    -- Batch 1/7 / Loss:  0.12415553
#    -- Batch 2/7 / Loss:  0.120978326
#    -- Batch 3/7 / Loss:  0.12421843
#    -- Batch 4/7 / Loss:  0.1216551
#    -- Batch 5/7 / Loss:  0.12164578
#    -- Batch 6/7 / Loss:  0.11875581
#    -- Batch 7/7 / Loss:  0.13296047
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12348134}
#    Validation: {'f1': 0.9761819839477539, 'loss': 0.1411987990140915}
#    Saving to: epoch_81_model.ckpt
# Epoch 82/100
#    -- Batch 1/7 / Loss:  0.12667988
#    -- Batch 2/7 / Loss:  0.12126644
#    -- Batch 3/7 / Loss:  0.1230771
#    -- Batch 4/7 / Loss:  0.120630905
#    -- Batch 5/7 / Loss:  0.121158935
#    -- Batch 6/7 / Loss:  0.11912673
#    -- Batch 7/7 / Loss:  0.121805295
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12196362}
#    Validation: {'f1': 0.9754900932312012, 'loss': 0.14100639522075653}
#    Saving to: epoch_82_model.ckpt
# Epoch 83/100
#    -- Batch 1/7 / Loss:  0.12101406
#    -- Batch 2/7 / Loss:  0.120231055
#    -- Batch 3/7 / Loss:  0.12325354
#    -- Batch 4/7 / Loss:  0.11808643
#    -- Batch 5/7 / Loss:  0.119411744
#    -- Batch 6/7 / Loss:  0.121496
#    -- Batch 7/7 / Loss:  0.11902283
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12035938}
#    Validation: {'f1': 0.9762951135635376, 'loss': 0.13947132229804993}
#    Saving to: epoch_83_model.ckpt
# Epoch 84/100
#    -- Batch 1/7 / Loss:  0.12171494
#    -- Batch 2/7 / Loss:  0.11748483
#    -- Batch 3/7 / Loss:  0.11584061
#    -- Batch 4/7 / Loss:  0.1157512
#    -- Batch 5/7 / Loss:  0.12814656
#    -- Batch 6/7 / Loss:  0.12228884
#    -- Batch 7/7 / Loss:  0.120124415
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.12019305}
#    Validation: {'f1': 0.9751520156860352, 'loss': 0.1399359554052353}
#    Saving to: epoch_84_model.ckpt
# Epoch 85/100
#    -- Batch 1/7 / Loss:  0.12265953
#    -- Batch 2/7 / Loss:  0.11903229
#    -- Batch 3/7 / Loss:  0.12334094
#    -- Batch 4/7 / Loss:  0.116231374
#    -- Batch 5/7 / Loss:  0.12025875
#    -- Batch 6/7 / Loss:  0.11735507
#    -- Batch 7/7 / Loss:  0.11501445
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11912749}
#    Validation: {'f1': 0.9764223098754883, 'loss': 0.1373637169599533}
#    Saving to: epoch_85_model.ckpt
# Epoch 86/100
#    -- Batch 1/7 / Loss:  0.11644323
#    -- Batch 2/7 / Loss:  0.11748664
#    -- Batch 3/7 / Loss:  0.11684113
#    -- Batch 4/7 / Loss:  0.11564904
#    -- Batch 5/7 / Loss:  0.11803678
#    -- Batch 6/7 / Loss:  0.117330804
#    -- Batch 7/7 / Loss:  0.11959107
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.117339805}
#    Validation: {'f1': 0.9751266241073608, 'loss': 0.13821886479854584}
#    Saving to: epoch_86_model.ckpt
# Epoch 87/100
#    -- Batch 1/7 / Loss:  0.121067785
#    -- Batch 2/7 / Loss:  0.117257394
#    -- Batch 3/7 / Loss:  0.11849523
#    -- Batch 4/7 / Loss:  0.11488975
#    -- Batch 5/7 / Loss:  0.11966336
#    -- Batch 6/7 / Loss:  0.11673499
#    -- Batch 7/7 / Loss:  0.11510157
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11760144}
#    Validation: {'f1': 0.9759607911109924, 'loss': 0.1363036036491394}
#    Saving to: epoch_87_model.ckpt
# Epoch 88/100
#    -- Batch 1/7 / Loss:  0.113906875
#    -- Batch 2/7 / Loss:  0.12004217
#    -- Batch 3/7 / Loss:  0.114217035
#    -- Batch 4/7 / Loss:  0.11595666
#    -- Batch 5/7 / Loss:  0.118955635
#    -- Batch 6/7 / Loss:  0.113348156
#    -- Batch 7/7 / Loss:  0.11540133
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1159754}
#    Validation: {'f1': 0.9761849641799927, 'loss': 0.1349666714668274}
#    Saving to: epoch_88_model.ckpt
# Epoch 89/100
#    -- Batch 1/7 / Loss:  0.11704905
#    -- Batch 2/7 / Loss:  0.113350354
#    -- Batch 3/7 / Loss:  0.1148272
#    -- Batch 4/7 / Loss:  0.11719781
#    -- Batch 5/7 / Loss:  0.11570412
#    -- Batch 6/7 / Loss:  0.11251828
#    -- Batch 7/7 / Loss:  0.11731148
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11542261}
#    Validation: {'f1': 0.976499080657959, 'loss': 0.13401658833026886}
#    Saving to: epoch_89_model.ckpt
# Epoch 90/100
#    -- Batch 1/7 / Loss:  0.1118257
#    -- Batch 2/7 / Loss:  0.111789234
#    -- Batch 3/7 / Loss:  0.11285276
#    -- Batch 4/7 / Loss:  0.11176287
#    -- Batch 5/7 / Loss:  0.116702415
#    -- Batch 6/7 / Loss:  0.11424211
#    -- Batch 7/7 / Loss:  0.11678571
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11370869}
#    Validation: {'f1': 0.9752211570739746, 'loss': 0.13511675596237183}
#    Saving to: epoch_90_model.ckpt
# Epoch 91/100
#    -- Batch 1/7 / Loss:  0.11527507
#    -- Batch 2/7 / Loss:  0.111756
#    -- Batch 3/7 / Loss:  0.1130272
#    -- Batch 4/7 / Loss:  0.11116932
#    -- Batch 5/7 / Loss:  0.12146044
#    -- Batch 6/7 / Loss:  0.110952176
#    -- Batch 7/7 / Loss:  0.110740334
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11348294}
#    Validation: {'f1': 0.9748971462249756, 'loss': 0.13432204723358154}
#    Saving to: epoch_91_model.ckpt
# Epoch 92/100
#    -- Batch 1/7 / Loss:  0.113171875
#    -- Batch 2/7 / Loss:  0.1129943
#    -- Batch 3/7 / Loss:  0.11255864
#    -- Batch 4/7 / Loss:  0.113049045
#    -- Batch 5/7 / Loss:  0.112479225
#    -- Batch 6/7 / Loss:  0.10751216
#    -- Batch 7/7 / Loss:  0.10956896
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.111619174}
#    Validation: {'f1': 0.9770803451538086, 'loss': 0.1304251253604889}
#    Saving to: epoch_92_model.ckpt
# Epoch 93/100
#    -- Batch 1/7 / Loss:  0.10871106
#    -- Batch 2/7 / Loss:  0.114098914
#    -- Batch 3/7 / Loss:  0.1144764
#    -- Batch 4/7 / Loss:  0.11166182
#    -- Batch 5/7 / Loss:  0.109950714
#    -- Batch 6/7 / Loss:  0.107906796
#    -- Batch 7/7 / Loss:  0.10624529
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.11043585}
#    Validation: {'f1': 0.976596474647522, 'loss': 0.13023141026496887}
#    Saving to: epoch_93_model.ckpt
# Epoch 94/100
#    -- Batch 1/7 / Loss:  0.10789295
#    -- Batch 2/7 / Loss:  0.114342496
#    -- Batch 3/7 / Loss:  0.1131972
#    -- Batch 4/7 / Loss:  0.10818247
#    -- Batch 5/7 / Loss:  0.10668032
#    -- Batch 6/7 / Loss:  0.10810312
#    -- Batch 7/7 / Loss:  0.11103116
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10991853}
#    Validation: {'f1': 0.9760540127754211, 'loss': 0.13034804165363312}
#    Saving to: epoch_94_model.ckpt
# Epoch 95/100
#    -- Batch 1/7 / Loss:  0.10610043
#    -- Batch 2/7 / Loss:  0.11140886
#    -- Batch 3/7 / Loss:  0.11485995
#    -- Batch 4/7 / Loss:  0.10414779
#    -- Batch 5/7 / Loss:  0.10882532
#    -- Batch 6/7 / Loss:  0.10744396
#    -- Batch 7/7 / Loss:  0.107651465
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10863398}
#    Validation: {'f1': 0.9766362905502319, 'loss': 0.1287064105272293}
#    Saving to: epoch_95_model.ckpt
# Epoch 96/100
#    -- Batch 1/7 / Loss:  0.1084301
#    -- Batch 2/7 / Loss:  0.10784499
#    -- Batch 3/7 / Loss:  0.1063398
#    -- Batch 4/7 / Loss:  0.10831027
#    -- Batch 5/7 / Loss:  0.105027325
#    -- Batch 6/7 / Loss:  0.10386621
#    -- Batch 7/7 / Loss:  0.10881526
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10694771}
#    Validation: {'f1': 0.9771641492843628, 'loss': 0.12694112956523895}
#    Saving to: epoch_96_model.ckpt
# Epoch 97/100
#    -- Batch 1/7 / Loss:  0.10743175
#    -- Batch 2/7 / Loss:  0.104247674
#    -- Batch 3/7 / Loss:  0.10739356
#    -- Batch 4/7 / Loss:  0.10527092
#    -- Batch 5/7 / Loss:  0.105797924
#    -- Batch 6/7 / Loss:  0.105542146
#    -- Batch 7/7 / Loss:  0.1041526
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10569094}
#    Validation: {'f1': 0.9768490791320801, 'loss': 0.1270744353532791}
#    Saving to: epoch_97_model.ckpt
# Epoch 98/100
#    -- Batch 1/7 / Loss:  0.10238196
#    -- Batch 2/7 / Loss:  0.11236886
#    -- Batch 3/7 / Loss:  0.10087338
#    -- Batch 4/7 / Loss:  0.11607335
#    -- Batch 5/7 / Loss:  0.103508234
#    -- Batch 6/7 / Loss:  0.10801623
#    -- Batch 7/7 / Loss:  0.103740245
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1067089}
#    Validation: {'f1': 0.9764804840087891, 'loss': 0.1270541548728943}
#    Saving to: epoch_98_model.ckpt
# Epoch 99/100
#    -- Batch 1/7 / Loss:  0.10987157
#    -- Batch 2/7 / Loss:  0.10129427
#    -- Batch 3/7 / Loss:  0.10533642
#    -- Batch 4/7 / Loss:  0.10109233
#    -- Batch 5/7 / Loss:  0.10386147
#    -- Batch 6/7 / Loss:  0.104915366
#    -- Batch 7/7 / Loss:  0.1041565
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.10436113}
#    Validation: {'f1': 0.974993884563446, 'loss': 0.12839077413082123}
#    Saving to: epoch_99_model.ckpt
# Epoch 100/100
#    -- Batch 1/7 / Loss:  0.10431948
#    -- Batch 2/7 / Loss:  0.10705167
#    -- Batch 3/7 / Loss:  0.108372785
#    -- Batch 4/7 / Loss:  0.10134984
#    -- Batch 5/7 / Loss:  0.099377014
#    -- Batch 6/7 / Loss:  0.10341575
#    -- Batch 7/7 / Loss:  0.104590744
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.104068175}
#    Validation: {'f1': 0.976807713508606, 'loss': 0.12477555871009827}
#    Saving to: epoch_100_model.ckpt

# %% [markdown]
# ## Plot training and validation histories

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.savefig("Plot Training and Validation Histories (N2)")
plt.show()

# %% [markdown]
# ## Evaluate on single test-set image

# %%
# Predict on a test image
x_test, y_test = test_dataset[0]
if gpu:
  x_test = x_test.to(device)
  y_test = y_test.to(device)
pred = model(x_test.view(1, 1, x_test.shape[1], x_test.shape[2])).argmax(1).cpu().numpy()

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")

plot_image_with_segmentation(x_test.cpu(), y_test.cpu(), ax=ax1)
plot_image_with_segmentation(x_test.cpu(), pred, ax=ax2)

plt.savefig("Evaluation on Single Test-set Image (N2)")
plt.show()

# %% [markdown]
# ## Evaluate on whole test-set

# %%
# OBS: Returns batch-wise metrics, but test_loader has batch_size = 1
f1_test_scores = evaluate_model(model, test_loader, metrics, reduction=False)["f1"]

print("Test cases:", len(f1_test_scores))
print("Mean F1:   ", np.mean(f1_test_scores))
print("STD  F1:   ", np.std(f1_test_scores))
print("Min. F1:   ", np.min(f1_test_scores))
# Out:
# Test cases: 123
# Mean F1:    0.9735332150769428
# STD  F1:    0.016701192400709452
# Min. F1:    0.9080529808998108
